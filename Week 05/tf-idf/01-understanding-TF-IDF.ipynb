# %% [markdown]
# # Understanding TF-IDF
#
# In this section we will work with texts and derive weighted metrics based on words (or terms) frequencies within these texts. More precisely, we will look at the _TF-IDF_ metric, which stands for _Term Frequency-Inverse Document Frequency_, to produce our metrics which will allow us to measure and evaluate how important certain words are in documents that are part of our IMDb corpus. The "texts" or "documents" we will look at are 'plot' descriptions in the IMDb dataset.

# %%
import pandas as pd
import nltk
import string
from nltk import word_tokenize
from nltk.corpus import stopwords

# %% [markdown]
# ## Loading the IMDb dataset
#
# Load the IMDb dataset and look closely at the 'Plot' column

# %%
df = pd.read_csv(r"C:\Users\Gebruiker\Documents\CODE\Master\Personalisation\INFOMPPM_local\Week 05\data\imdb.csv")

# %%
df.shape
# Out:
# (5380, 27)

# %%
df.head(1)
# Out:
#         Title  Year  Rated     Released Runtime                 Genre  \
# 0  The Player  2015  TV-14  24 Sep 2015  60 min  Action, Crime, Drama
#
#   Director                 Writer  \
# 0      NaN  John Fox, John Rogers
#
#                                               Actors  \
# 0  Philip Winchester, Damon Gupton, Wesley Snipes...
#
#                                                 Plot  ... imdbRating  \
# 0  A former intelligence and FBI officer, who now...  ...        7.1
#
#   imdbVotes     imdbID    Type  DVD BoxOffice  Production  Website Response  \
# 0     6,331  tt4474310  series  NaN       NaN         NaN      NaN     True
#
#   tomatoURL
# 0       NaN
#
# [1 rows x 27 columns]

# %%
stop_words = stopwords.words('english')

def preprocess(df, column):
    df["preprocessed"] = column.str.lower()# Lowercase
    df['preprocessed'] = df['preprocessed'].str.translate(str.maketrans(' ', ' ', string.digits))# Remove digits
    df['preprocessed'] = df['preprocessed'].str.translate(str.maketrans(' ', ' ', string.punctuation))# Remove punctuation
    df['preprocessed'] = df['preprocessed'].str.strip() # Remove whitespaces
    df['preprocessed'] = df['preprocessed'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in (stop_words)]))# Remove stopwords
    return df

preprocess(df,df["Plot"])


pd.options.display.max_colwidth = 1000 
df[["preprocessed","Plot"]].head()
# Out:
#                                                                                                                                                              preprocessed  \
# 0  former intelligence fbi officer works security expert las vegas recruited mysterious pit boss mr johnson based tips try prevent crimes rich place bets chances success
# 1                                                                                           bus driver sewer worker friend struggle strike rich wives look weary patience
# 2                                                                                                                          misadventures misfit pt boat crew world war ii
# 3                                                                                 witch married ordinary man cannot resist using magic powers solve problems family faces
# 4                                                                                                    staff army hospital korean war find laughter best way deal situation
#
#                                                                                                                                                                                                                                          Plot
# 0  A former intelligence and FBI officer, who now works as a security expert in Las Vegas, is recruited by mysterious pit boss Mr. Johnson to, based on his tips, try to prevent crimes, while the rich place bets on his chances of success.
# 1                                                                                                                          A bus driver and his sewer worker friend struggle to strike it rich while their wives look on with weary patience.
# 2                                                                                                                                                                             The misadventures of a misfit PT Boat crew during World War II.
# 3                                                                                                                             A witch married to an ordinary man cannot resist using her magic powers to solve the problems her family faces.
# 4                                                                                                                            The staff of an army hospital in the Korean war find that laughter is the best way to deal with their situation.

# %% [markdown]
# ## Create a data structure
#
# We need a custom data structure to carry out our TF-IDF calculations. Create a python dictionary having for keys the indices of the dataframe above and for value another dictionary with 'plot' as an entry for each row in the dataframe.

# %%
plot_dict = {}
for row, plot in enumerate(df["preprocessed"]):
    plot_dict.update({row : plot})

# %% [markdown]
# ## Tokenize and filter
#
# Now that we have the plot of each IMDb entry in our dictionary, it is time to tokenize each plot's text and clean it up. Do we need punctuations as part of our tokens? Are there "stop words" we could get rid off? Please complete the following tokenizer function utilising the spacy library (which you used in Data Mining - also, remember to uncomment the first line if you are using spacy for the first time). When this is done, augment your custom dictionary with the plot's tokens for each entry.

# %%
nltk.download('stopwords')
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
lemmatizer = nltk.stem.WordNetLemmatizer()

def split_and_stop(text):
    
    word_tokenize(text) 

    
    return # code goes here
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Gebruiker\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
t = "Hello, This is a #test"

word_tokenize(t)
# Out:
# ['Hello', ',', 'This', 'is', 'a', '#', 'test']

# %%
for row, plot in plot_dict.items():
    plot_dict.update({row : word_tokenize(plot)})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 for row, plot in plot_dict.items():
# ----> 2     plot_dict.update({row : word_tokenize(plot)})
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\__init__.py:129, in word_tokenize(text, language, preserve_line)
#     114 def word_tokenize(text, language="english", preserve_line=False):
#     115     """
#     116     Return a tokenized copy of *text*,
#     117     using NLTK's recommended word tokenizer
#    (...)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\__init__.py:107, in sent_tokenize(text, language)
#      97 """
#      98 Return a sentence-tokenized copy of *text*,
#      99 using NLTK's recommended sentence tokenizer
#    (...)
#     104 :param language: the model name in the Punkt corpus
#     105 """
#     106 tokenizer = load(f"tokenizers/punkt/{language}.pickle")
# --> 107 return tokenizer.tokenize(text)
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\punkt.py:1281, in PunktSentenceTokenizer.tokenize(self, text, realign_boundaries)
#    1277 def tokenize(self, text: str, realign_boundaries: bool = True) -> List[str]:
#    1278     """
#    1279     Given a text, returns a list of the sentences in that text.
#    1280     """
# -> 1281     return list(self.sentences_from_text(text, realign_boundaries))
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\punkt.py:1341, in PunktSentenceTokenizer.sentences_from_text(self, text, realign_boundaries)
#    1332 def sentences_from_text(
#    1333     self, text: str, realign_boundaries: bool = True
#    1334 ) -> List[str]:
#    1335     """
#    1336     Given a text, generates the sentences in that text by only
#    1337     testing candidate sentence breaks. If realign_boundaries is
#    1338     True, includes in the sentence closing punctuation that
#    1339     follows the period.
#    1340     """
# -> 1341     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\punkt.py:1341, in <listcomp>(.0)
#    1332 def sentences_from_text(
#    1333     self, text: str, realign_boundaries: bool = True
#    1334 ) -> List[str]:
#    1335     """
#    1336     Given a text, generates the sentences in that text by only
#    1337     testing candidate sentence breaks. If realign_boundaries is
#    1338     True, includes in the sentence closing punctuation that
#    1339     follows the period.
#    1340     """
# -> 1341     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\punkt.py:1329, in PunktSentenceTokenizer.span_tokenize(self, text, realign_boundaries)
#    1327 if realign_boundaries:
#    1328     slices = self._realign_boundaries(text, slices)
# -> 1329 for sentence in slices:
#    1330     yield (sentence.start, sentence.stop)
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\punkt.py:1459, in PunktSentenceTokenizer._realign_boundaries(self, text, slices)
#    1446 """
#    1447 Attempts to realign punctuation that falls after the period but
#    1448 should otherwise be included in the same sentence.
#    (...)
#    1456     ["(Sent1.)", "Sent2."].
#    1457 """
#    1458 realign = 0
# -> 1459 for sentence1, sentence2 in _pair_iter(slices):
#    1460     sentence1 = slice(sentence1.start + realign, sentence1.stop)
#    1461     if not sentence2:
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\punkt.py:321, in _pair_iter(iterator)
#     319 iterator = iter(iterator)
#     320 try:
# --> 321     prev = next(iterator)
#     322 except StopIteration:
#     323     return
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\punkt.py:1431, in PunktSentenceTokenizer._slices_from_text(self, text)
#    1429 def _slices_from_text(self, text: str) -> Iterator[slice]:
#    1430     last_break = 0
# -> 1431     for match, context in self._match_potential_end_contexts(text):
#    1432         if self.text_contains_sentbreak(context):
#    1433             yield slice(last_break, match.end())
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\punkt.py:1395, in PunktSentenceTokenizer._match_potential_end_contexts(self, text)
#    1393 previous_slice = slice(0, 0)
#    1394 previous_match = None
# -> 1395 for match in self._lang_vars.period_context_re().finditer(text):
#    1396
#    1397     # Get the slice of the previous word
#    1398     before_text = text[previous_slice.stop : match.start()]
#    1399     index_after_last_space = self._get_last_whitespace_index(before_text)
#
# TypeError: expected string or bytes-like object, got 'list'

# %%
# Out:
# {0: ['former',
#   'intelligence',
#   'fbi',
#   'officer',
#   'works',
#   'security',
#   'expert',
#   'las',
#   'vegas',
#   'recruited',
#   'mysterious',
#   'pit',
#   'boss',
#   'mr',
#   'johnson',
#   'based',
#   'tips',
#   'try',
#   'prevent',
#   'crimes',
#   'rich',
#   'place',
#   'bets',
#   'chances',
#   'success'],
#  1: ['bus',
#   'driver',
#   'sewer',
#   'worker',
#   'friend',
#   'struggle',
#   'strike',
#   'rich',
#   'wives',
#   'look',
#   'weary',
#   'patience'],
#  2: ['misadventures', 'misfit', 'pt', 'boat', 'crew', 'world', 'war', 'ii'],
#  3: ['witch',
#   'married',
#   'ordinary',
#   'man',
#   'can',
#   'not',
#   'resist',
#   'using',
#   'magic',
#   'powers',
#   'solve',
#   'problems',
#   'family',
#   'faces'],
#  4: ['staff',
#   'army',
#   'hospital',
#   'korean',
#   'war',
#   'find',
#   'laughter',
#   'best',
#   'way',
#   'deal',
#   'situation'],
#  5: ['veteran',
#   'cop',
#   'years',
#   'experience',
#   'teamed',
#   'young',
#   'inspector',
#   'solve',
#   'crimes',
#   'san',
#   'francisco'],
#  6: ['four',
#   'vietnam',
#   'vets',
#   'framed',
#   'crime',
#   'didnt',
#   'commit',
#   'help',
#   'innocent',
#   'run',
#   'military'],
#  7: ['resplendent',
#   'authentic',
#   'music',
#   'fashion',
#   'vibe',
#   'miami',
#   'vice',
#   'follows',
#   'two',
#   'undercover',
#   'detectives',
#   'extended',
#   'team',
#   'mean',
#   'streets',
#   'miami'],
#  8: ['orphan',
#   'girl',
#   'sent',
#   'elderly',
#   'brother',
#   'sister',
#   'mistake',
#   'charms',
#   'new',
#   'home',
#   'community',
#   'fiery',
#   'spirit',
#   'imagination'],
#  9: ['saga',
#   'high',
#   'fashion',
#   'glamour',
#   'honor',
#   'romance',
#   'passion',
#   'importantly',
#   'family'],
#  10: ['ten',
#   'television',
#   'drama',
#   'films',
#   'one',
#   'based',
#   'one',
#   'ten',
#   'commandments'],
#  11: ['cases',
#   'adventures',
#   'police',
#   'forces',
#   'around',
#   'sparta',
#   'mississippi'],
#  12: ['brothers',
#   'brian',
#   'joe',
#   'hackett',
#   'attempt',
#   'run',
#   'airline',
#   'new',
#   'england',
#   'island',
#   'nantucket',
#   'surrounded',
#   'various',
#   'wacky',
#   'friends',
#   'employees'],
#  13: ['di',
#   'jack',
#   'frost',
#   'unconventional',
#   'policeman',
#   'sympathy',
#   'underdog',
#   'instinct',
#   'moral',
#   'justice',
#   'sloppy',
#   'disorganized',
#   'disrespectful',
#   'attracts',
#   'trouble',
#   'like',
#   'magnet'],
#  14: ['earth',
#   'embroiled',
#   'desperate',
#   'war',
#   'alien',
#   'invaders',
#   'series',
#   'focuses',
#   'one',
#   'squadron',
#   'marine',
#   'pilots',
#   'involved'],
#  15: ['group',
#   'aliens',
#   'sent',
#   'earth',
#   'disguised',
#   'human',
#   'family',
#   'experience',
#   'report',
#   'life',
#   'rd',
#   'planet',
#   'sun'],
#  16: ['year',
#   'old',
#   'high',
#   'school',
#   'student',
#   'sabrina',
#   'spellman',
#   'finds',
#   'shes',
#   'witch',
#   'two',
#   'witchy',
#   'aunts',
#   'zelda',
#   'hilda',
#   'offered',
#   'guidance',
#   'control',
#   'newdiscovered',
#   'magical',
#   'powers',
#   'along',
#   'salem',
#   'talking',
#   'black',
#   'cat',
#   'used',
#   'warlock'],
#  17: ['young',
#   'woman',
#   'forced',
#   'fulfill',
#   'destiny',
#   'fighting',
#   'vampires',
#   'demons',
#   'help',
#   'friends',
#   'struggling',
#   'live',
#   'normal',
#   'teenage',
#   'life',
#   'heart',
#   'break',
#   'drama'],
#  18: ['first', 'got', 'fired', 'got', 'fired'],
#  19: ['end',
#   'world',
#   'war',
#   'bannerman',
#   'family',
#   'reopens',
#   'grand',
#   'hotel',
#   'lengthy',
#   'closure',
#   'costly',
#   'refurbishing',
#   'hotel',
#   'family',
#   'long',
#   'time',
#   'john'],
#  20: ['secret',
#   'military',
#   'team',
#   'sg',
#   'formed',
#   'explore',
#   'recently',
#   'discovered',
#   'stargates'],
#  21: ['single',
#   'mother',
#   'applegate',
#   'tries',
#   'find',
#   'love',
#   'new',
#   'boyfriend',
#   'diego',
#   'father',
#   'disapproves',
#   'gets',
#   'help',
#   'two',
#   'brothers',
#   'one',
#   'voluntarily',
#   'mute',
#   'two'],
#  22: ['amphibious',
#   'sharklike',
#   'monster',
#   'terrorizes',
#   'abandoned',
#   'secret',
#   'military',
#   'base',
#   'people',
#   'live',
#   'island',
#   'located',
#   'marine',
#   'biologist',
#   'well',
#   'several',
#   'people'],
#  23: ['four',
#   'female',
#   'new',
#   'yorkers',
#   'gossip',
#   'sex',
#   'lives',
#   'lack',
#   'thereof',
#   'find',
#   'new',
#   'ways',
#   'deal',
#   'woman'],
#  24: ['commander',
#   'david',
#   'wheeler',
#   'arrested',
#   'seemingly',
#   'motiveless',
#   'attack',
#   'mysterious',
#   'vessel',
#   'son',
#   'richard',
#   'along',
#   'two',
#   'friends',
#   'embarks',
#   'search',
#   'topsecret',
#   'information',
#   'might',
#   'clear',
#   'name'],
#  25: ['based',
#   'books',
#   'marc',
#   'brown',
#   'adventures',
#   'arthur',
#   'yearold',
#   'aardvark',
#   'family',
#   'friends',
#   'grow',
#   'learn',
#   'good',
#   'neighbors',
#   'one',
#   'another'],
#  26: ['three',
#   'superpowered',
#   'little',
#   'girls',
#   'constantly',
#   'save',
#   'world',
#   'least',
#   'city',
#   'townsville',
#   'monsters',
#   'wouldbe',
#   'conquerers',
#   'gross',
#   'things'],
#  27: ['yearold', 'exdrug', 'addict', 'returns', 'high', 'school', 'freshman'],
#  28: ['brendon',
#   'small',
#   'ambitious',
#   'eightyearold',
#   'filmmaker',
#   'shoots',
#   'movies',
#   'basement',
#   'two',
#   'best',
#   'friends',
#   'coming',
#   'terms',
#   'adolescence',
#   'life',
#   'relationships'],
#  29: ['group',
#   'geneticallyenhanced',
#   'children',
#   'escape',
#   'lab',
#   'project',
#   'years',
#   'later',
#   'meet',
#   'max',
#   'one',
#   'escapees',
#   'works',
#   'messenger',
#   'service',
#   'postapocalyptic',
#   'pacific',
#   'northwest'],
#  30: ['follow',
#   'dysfunctional',
#   'green',
#   'family',
#   'parents',
#   'face',
#   'midlife',
#   'crisis',
#   'kids',
#   'go',
#   'teenage',
#   'years'],
#  31: ['yugi',
#   'moto',
#   'solves',
#   'ancient',
#   'egyptian',
#   'puzzle',
#   'brings',
#   'forth',
#   'dark',
#   'powerful',
#   'alter',
#   'ego',
#   'whenever',
#   'friends',
#   'threatened',
#   'evil',
#   'duel',
#   'monster',
#   'card',
#   'game',
#   'alter',
#   'ego',
#   'breaks',
#   'save'],
#  32: ['johnny',
#   'smith',
#   'leading',
#   'idyllic',
#   'smalltown',
#   'life',
#   'employed',
#   'science',
#   'teacher',
#   'johnny',
#   'takes',
#   'great',
#   'pleasure',
#   'showing',
#   'young',
#   'students',
#   'wonders',
#   'natural',
#   'world'],
#  33: ['single',
#   'bachelor',
#   'dates',
#   'multiple',
#   'women',
#   'several',
#   'weeks',
#   'narrowing',
#   'hopefully',
#   'find',
#   'true',
#   'love'],
#  34: ['troubled',
#   'youth',
#   'becomes',
#   'embroiled',
#   'lives',
#   'closeknit',
#   'group',
#   'people',
#   'wealthy',
#   'upperclass',
#   'neighborhood',
#   'newport',
#   'beach',
#   'orange',
#   'county',
#   'california'],
#  35: ['film',
#   'star',
#   'vince',
#   'chase',
#   'navigates',
#   'vapid',
#   'terrain',
#   'los',
#   'angeles',
#   'close',
#   'circle',
#   'friends',
#   'trusty',
#   'agent'],
#  36: ['best',
#   'friend',
#   'murdered',
#   'father',
#   'removed',
#   'county',
#   'sheriff',
#   'veronica',
#   'mars',
#   'dedicates',
#   'life',
#   'cracking',
#   'toughest',
#   'mysteries',
#   'affluent',
#   'town',
#   'neptune'],
#  37: ['onehour',
#   'weekly',
#   'docusoap',
#   'creatorexecutive',
#   'producer',
#   'american',
#   'chopper',
#   'follows',
#   'group',
#   'reallife',
#   'paranormal',
#   'researchers',
#   'investigate',
#   'haunted',
#   'houses',
#   'throughout'],
#  38: ['creators',
#   'seth',
#   'green',
#   'matthew',
#   'senreich',
#   'robot',
#   'chicken',
#   'stopmotion',
#   'animation',
#   'demented',
#   'twist'],
#  39: ['grand',
#   'army',
#   'republic',
#   'led',
#   'yoda',
#   'mace',
#   'windu',
#   'obiwan',
#   'kenobi',
#   'anakin',
#   'skywalker',
#   'jedi',
#   'knights',
#   'fights',
#   'droid',
#   'army',
#   'separatists'],
#  40: ['forensic',
#   'anthropologist',
#   'dr',
#   'temperance',
#   'bones',
#   'brennan',
#   'cocky',
#   'fbi',
#   'special',
#   'agent',
#   'seeley',
#   'booth',
#   'build',
#   'team',
#   'investigate',
#   'murders',
#   'quite',
#   'often',
#   'isnt',
#   'examine',
#   'rotten',
#   'flesh',
#   'mere',
#   'bones'],
#  41: ['five',
#   'friends',
#   'big',
#   'egos',
#   'slightly',
#   'arrogant',
#   'attitudes',
#   'proprietors',
#   'irish',
#   'bar',
#   'philadelphia'],
#  42: ['reallife',
#   'figures',
#   'cold',
#   'war',
#   'era',
#   'mix',
#   'fictional',
#   'story',
#   'based',
#   'group',
#   'cia',
#   'operatives',
#   'counterparts',
#   'kgb',
#   'mi',
#   'mossad'],
#  43: ['novice',
#   'sleuth',
#   'hired',
#   'police',
#   'cons',
#   'thinking',
#   'psychic',
#   'powers',
#   'help',
#   'solve',
#   'crimes',
#   'assistance',
#   'reluctant',
#   'best',
#   'friend',
#   'duo',
#   'take',
#   'series',
#   'complicated',
#   'cases'],
#  44: ['trials',
#   'tribulations',
#   'small',
#   'town',
#   'texas',
#   'football',
#   'players',
#   'friends',
#   'family',
#   'coaching',
#   'staff'],
#  45: ['two',
#   'couples',
#   'single',
#   'friend',
#   'different',
#   'stages',
#   'relationships',
#   'deal',
#   'complications',
#   'dating',
#   'commitment',
#   'marriage'],
#  46: ['best',
#   'minds',
#   'us',
#   'tucked',
#   'away',
#   'remote',
#   'town',
#   'build',
#   'futuristic',
#   'inventions',
#   'governments',
#   'benefit'],
#  47: ['common',
#   'people',
#   'discover',
#   'super',
#   'powers',
#   'lives',
#   'intertwine',
#   'devastating',
#   'event',
#   'must',
#   'prevented'],
#  48: ['angel',
#   'offers',
#   'jaded',
#   'oklahoma',
#   'city',
#   'police',
#   'detective',
#   'chance',
#   'redeem',
#   'life'],
#  49: ['former',
#   'police',
#   'officer',
#   'returns',
#   'force',
#   'wrongly',
#   'imprisoned',
#   'years'],
#  50: ['shaun',
#   'sheep',
#   'doesnt',
#   'follow',
#   'flock',
#   'fact',
#   'leads',
#   'sorts',
#   'scrapes',
#   'scraps',
#   'turning',
#   'peace',
#   'valley',
#   'mayhem',
#   'meadow',
#   'shaun',
#   'pals',
#   'run'],
#  51: ['follows', 'four', 'friends', 'antics', 'final', 'years', 'school'],
#  52: ['foundling',
#   'heathcliff',
#   'raised',
#   'wealthy',
#   'earnshaws',
#   'yorkshire',
#   'later',
#   'life',
#   'launches',
#   'vendetta',
#   'family'],
#  53: ['sonny',
#   'talented',
#   'midwestern',
#   'girl',
#   'nationwide',
#   'talent',
#   'search',
#   'move',
#   'los',
#   'angeles',
#   'star',
#   'popular',
#   'television',
#   'series',
#   'sonnys',
#   'home',
#   'work',
#   'life',
#   'documented',
#   'along',
#   'adjustment',
#   'life',
#   'spotlight'],
#  54: ['cora',
#   'simmons',
#   'living',
#   'home',
#   'grown',
#   'adult',
#   'challenges',
#   'especially',
#   'mr',
#   'brown',
#   'daddy'],
#  55: ['story',
#   'venezuelan',
#   'revolutionary',
#   'ilich',
#   'ramírez',
#   'sánchez',
#   'founded',
#   'worldwide',
#   'terrorist',
#   'organization',
#   'raided',
#   'opec',
#   'meeting'],
#  56: ['emma',
#   'woodhouse',
#   'seems',
#   'perfectly',
#   'content',
#   'loving',
#   'father',
#   'cares',
#   'friends',
#   'home',
#   'emma',
#   'terrible',
#   'habit',
#   'matchmaking',
#   'can',
#   'not',
#   'resist',
#   'finding',
#   'suitors'],
#  57: ['watch',
#   'story',
#   'historys',
#   'greatest',
#   'gladiator',
#   'unfold',
#   'graphic',
#   'violence',
#   'passions',
#   'women',
#   'love',
#   'spartacus'],
#  58: ['crime',
#   'drama',
#   'series',
#   'starring',
#   'idris',
#   'elba',
#   'neargenius',
#   'murder',
#   'detective',
#   'whose',
#   'brilliant',
#   'mind',
#   'cant',
#   'always',
#   'save',
#   'dangerous',
#   'violence',
#   'passions'],
#  59: ['rogue',
#   'assassin',
#   'returns',
#   'take',
#   'secret',
#   'organization',
#   'trained'],
#  60: ['dr',
#   'daniel',
#   'pierce',
#   'eccentric',
#   'neuropsychiatrist',
#   'uses',
#   'unique',
#   'outlook',
#   'help',
#   'federal',
#   'government',
#   'solve',
#   'complex',
#   'criminal',
#   'cases'],
#  61: ['married',
#   'father',
#   'three',
#   'tries',
#   'maintain',
#   'manliness',
#   'world',
#   'increasingly',
#   'dominated',
#   'women'],
#  62: ['carrie',
#   'wells',
#   'former',
#   'police',
#   'detective',
#   'rare',
#   'ability',
#   'remember',
#   'virtually',
#   'everything',
#   'experiences',
#   'including',
#   'detailed',
#   'visual',
#   'recall',
#   'returns',
#   'police',
#   'work',
#   'uses',
#   'ability',
#   'solve',
#   'crimes'],
#  63: ['new',
#   'york',
#   'mobster',
#   'goes',
#   'hiding',
#   'rural',
#   'lillehammer',
#   'norway',
#   'testifying',
#   'former',
#   'associates'],
#  64: ['divorced',
#   'former',
#   'baseball',
#   'player',
#   'charlie',
#   'goodson',
#   'anger',
#   'management',
#   'therapist',
#   'teenage',
#   'daughter',
#   'obsessivecompulsive',
#   'disorder',
#   'purely',
#   'sexual',
#   'relationship'],
#  65: ['ciro',
#   'disregards',
#   'tradition',
#   'attempt',
#   'become',
#   'next',
#   'boss',
#   'crime',
#   'syndicate',
#   'internal',
#   'power',
#   'struggle',
#   'puts',
#   'entire',
#   'familys',
#   'life',
#   'risk'],
#  66: ['fifteen',
#   'years',
#   'permanent',
#   'global',
#   'blackout',
#   'group',
#   'revolutionaries',
#   'seeks',
#   'drive',
#   'occupying',
#   'force',
#   'posing',
#   'united',
#   'states',
#   'government'],
#  67: ['brilliant',
#   'charismatic',
#   'yet',
#   'psychotic',
#   'serial',
#   'killer',
#   'communicates',
#   'active',
#   'serial',
#   'killers',
#   'activates',
#   'cult',
#   'believers',
#   'following',
#   'every',
#   'command'],
#  68: ['year',
#   'new',
#   'earth',
#   'new',
#   'rules',
#   'thirty',
#   'years',
#   'various',
#   'alien',
#   'races',
#   'arrived',
#   'earth',
#   'landscape',
#   'completely',
#   'altered',
#   'terraformed',
#   'nearly',
#   'beyond',
#   'recognition'],
#  69: ['explores',
#   'early',
#   'relationship',
#   'renowned',
#   'psychiatrist',
#   'patient',
#   'young',
#   'fbi',
#   'criminal',
#   'profiler',
#   'haunted',
#   'ability',
#   'empathize',
#   'serial',
#   'killers'],
#  70: ['teen',
#   'troubled',
#   'past',
#   'reconnects',
#   'two',
#   'female',
#   'best',
#   'friends',
#   'childhood',
#   'becomes',
#   'prime',
#   'suspect',
#   'fellow',
#   'student',
#   'surprisingly',
#   'found',
#   'dead',
#   'home'],
#  71: ['ahsha',
#   'hayes',
#   'enters',
#   'wild',
#   'world',
#   'professional',
#   'basketball',
#   'tries',
#   'elite',
#   'la',
#   'devil',
#   'girls',
#   'dance',
#   'team',
#   'wishes',
#   'mother',
#   'sloane',
#   'former',
#   'dancer'],
#  72: ['grace',
#   'morally',
#   'emotionallyconflicted',
#   'undercover',
#   'detective',
#   'tormented',
#   'possibility',
#   'actions',
#   'contributed',
#   'sons',
#   'mysterious',
#   'death',
#   'quest',
#   'truth'],
#  73: ['returned',
#   'opens',
#   'small',
#   'mountain',
#   'community',
#   'rocked',
#   'core',
#   'several',
#   'local',
#   'people',
#   'presumed',
#   'dead',
#   'suddenly',
#   'reappear',
#   'homes',
#   'despite',
#   'passed',
#   'away'],
#  74: ['ichabod',
#   'crane',
#   'resurrected',
#   'pulled',
#   'two',
#   'half',
#   'centuries',
#   'time',
#   'unravel',
#   'mystery',
#   'dates',
#   'way',
#   'back',
#   'founding',
#   'fathers'],
#  75: ['various',
#   'chronicles',
#   'deception',
#   'intrigue',
#   'murder',
#   'around',
#   'frozen',
#   'minnesota',
#   'yet',
#   'tales',
#   'mysteriously',
#   'lead',
#   'back',
#   'one',
#   'way',
#   'another',
#   'fargo',
#   'nd'],
#  76: ['follows',
#   'story',
#   'claire',
#   'randall',
#   'married',
#   'combat',
#   'nurse',
#   'mysteriously',
#   'swept',
#   'back',
#   'time',
#   'immediately',
#   'thrown',
#   'unknown',
#   'world',
#   'life'],
#  77: ['follows',
#   'journey',
#   'time',
#   'traveler',
#   'postapocalyptic',
#   'future',
#   'appears',
#   'present',
#   'day',
#   'mission',
#   'locate',
#   'eradicate',
#   'source',
#   'deadly',
#   'plague',
#   'nearly',
#   'destroy',
#   'human',
#   'race'],
#  78: ['hiphop',
#   'mogul',
#   'must',
#   'choose',
#   'successor',
#   'among',
#   'three',
#   'sons',
#   'battling',
#   'control',
#   'multimillion',
#   'dollar',
#   'company',
#   'exwife',
#   'schemes',
#   'reclaim'],
#  79: ['matt',
#   'murdock',
#   'senses',
#   'superhumanly',
#   'enhanced',
#   'fights',
#   'crime',
#   'blind',
#   'lawyer',
#   'day',
#   'vigilante',
#   'night'],
#  80: ['catherine',
#   'cawood',
#   'sergeant',
#   'duty',
#   'flustered',
#   'nervous',
#   'accountant',
#   'kevin',
#   'weatherill',
#   'comes',
#   'west',
#   'yorkshire',
#   'station',
#   'report',
#   'crime'],
#  81: ['three',
#   'journalists',
#   'charles',
#   'bean',
#   'ellis',
#   'ashmead',
#   'bartlett',
#   'phillip',
#   'schuler',
#   'arrive',
#   'gallipoli',
#   'invading',
#   'british',
#   'allied',
#   'troops',
#   'report',
#   'war'],
#  82: ['man',
#   'struggling',
#   'faith',
#   'haunted',
#   'sins',
#   'past',
#   'suddenly',
#   'thrust',
#   'role',
#   'defending',
#   'humanity',
#   'gathering',
#   'forces',
#   'darkness'],
#  83: ['mysterious',
#   'object',
#   'crashes',
#   'earth',
#   'group',
#   'unconnected',
#   'strangers',
#   'die',
#   'energy',
#   'pulse',
#   'emits',
#   'reawaken',
#   'find',
#   'deemed',
#   'responsible',
#   'preventing',
#   'impending',
#   'apocalypse'],
#  84: ['series',
#   'detective',
#   'focuses',
#   'prime',
#   'suspect',
#   'murder',
#   'case',
#   'everyone',
#   'something',
#   'hide'],
#  85: ['remote',
#   'town',
#   'iceland',
#   'police',
#   'desperately',
#   'try',
#   'solve',
#   'crime',
#   'powerful',
#   'storm',
#   'descends',
#   'upon',
#   'town'],
#  86: ['tv',
#   'series',
#   'based',
#   'steven',
#   'soderberghs',
#   'girlfriend',
#   'experience',
#   'centered',
#   'life',
#   'new',
#   'york',
#   'call',
#   'girl'],
#  87: ['tony',
#   'emily',
#   'hughes',
#   'travel',
#   'france',
#   'yearold',
#   'son',
#   'oliver',
#   'family',
#   'holiday',
#   'turns',
#   'nightmare',
#   'oliver',
#   'disappears',
#   'large',
#   'celebrating',
#   'crowd',
#   'northern',
#   'france'],
#  88: ['russian',
#   'conflict',
#   'napoleon',
#   'reaches',
#   'peak',
#   'five',
#   'aristocratic',
#   'families',
#   'face',
#   'possibility',
#   'lives',
#   'changed',
#   'forever'],
#  89: ['starts',
#   'youtube',
#   'video',
#   'going',
#   'viral',
#   'soon',
#   'leads',
#   'problems',
#   'teenagers',
#   'lakewood',
#   'serves',
#   'catalyst',
#   'serial',
#   'killer'],
#  90: ['bombing',
#   'attack',
#   'killed',
#   'friends',
#   'border',
#   'guard',
#   'captain',
#   'wiktor',
#   'rebrow',
#   'trying',
#   'unravel',
#   'mystery',
#   'figure',
#   'happened',
#   'behind'],
#  91: ['finding',
#   'std',
#   'dylan',
#   'must',
#   'get',
#   'back',
#   'touch',
#   'every',
#   'girl',
#   'ever',
#   'sex',
#   'let',
#   'know',
#   'bad',
#   'news'],
#  92: ['tv',
#   'show',
#   'based',
#   'actioncomedy',
#   'rush',
#   'hour',
#   'films',
#   'la',
#   'cop',
#   'teams',
#   'detective',
#   'hong',
#   'kong'],
#  93: ['police',
#   'start',
#   'investigate',
#   'bones',
#   'young',
#   'man',
#   'found',
#   'footings',
#   'demolished',
#   'house',
#   'years',
#   'murder'],
#  94: ['average',
#   'yearold',
#   'man',
#   'gains',
#   'ability',
#   'use',
#   'full',
#   'extent',
#   'brains',
#   'capabilities',
#   'hired',
#   'fbi',
#   'consultant'],
#  95: ['community',
#   'rattled',
#   'politicians',
#   'son',
#   'presumed',
#   'murdered',
#   'years',
#   'ago',
#   'returns',
#   'home'],
#  96: ['eve',
#   'yearold',
#   'american',
#   'tourist',
#   'targeted',
#   'crazed',
#   'serial',
#   'killer',
#   'mick',
#   'taylor',
#   'survives',
#   'attack',
#   'embarks',
#   'mission',
#   'revenge'],
#  97: ['loss',
#   'parents',
#   'mysterious',
#   'fire',
#   'three',
#   'baudelaire',
#   'children',
#   'face',
#   'trials',
#   'tribulations',
#   'attempting',
#   'uncover',
#   'dark',
#   'family',
#   'secrets'],
#  98: ['government',
#   'employee',
#   'discovers',
#   'cause',
#   'tensions',
#   'two',
#   'political',
#   'parties',
#   'race',
#   'extraterrestrial',
#   'insects',
#   'eating',
#   'brains',
#   'politicians'],
#  99: ['supernatural',
#   'event',
#   'church',
#   'preacher',
#   'enlists',
#   'help',
#   'vampire',
#   'find',
#   'god'],
#  100: ['secret',
#   'story',
#   'reallife',
#   'double',
#   'murder',
#   'james',
#   'nesbitt',
#   'plays',
#   'colin',
#   'howell',
#   'respectable',
#   'dentist',
#   'pillar',
#   'community',
#   'became',
#   'killer',
#   'partnership',
#   'sunday'],
#  101: ['tv',
#   'show',
#   'based',
#   'popular',
#   'lethal',
#   'weapon',
#   'films',
#   'slightly',
#   'unhinged',
#   'cop',
#   'partnered',
#   'veteran',
#   'detective',
#   'trying',
#   'maintain',
#   'low',
#   'stress',
#   'level',
#   'life'],
#  102: ['vanessa',
#   'helsing',
#   'distant',
#   'relative',
#   'famous',
#   'vampire',
#   'hunter',
#   'abraham',
#   'van',
#   'helsing',
#   'resurrected',
#   'find',
#   'vampires',
#   'taken',
#   'world'],
#  103: ['brilliant',
#   'attorney',
#   'former',
#   'first',
#   'daughter',
#   'blackmailed',
#   'heading',
#   'unit',
#   'investigates',
#   'cases',
#   'wrongful',
#   'conviction'],
#  104: ['charismatic',
#   'defense',
#   'attorney',
#   'powerhouse',
#   'television',
#   'producer',
#   'work',
#   'together',
#   'control',
#   'media',
#   'following',
#   'highprofile',
#   'incident'],
#  105: ['series',
#   'centers',
#   'yearold',
#   'joshua',
#   'j',
#   'cody',
#   'moves',
#   'freewheeling',
#   'relatives',
#   'southern',
#   'california',
#   'beach',
#   'town',
#   'mother',
#   'dies',
#   'heroin',
#   'overdose',
#   'headed'],
#  106: ['nan'],
#  107: ['look',
#   'december',
#   'corruption',
#   'scandal',
#   'turkey',
#   'viewpoint',
#   'erdogan',
#   'government'],
#  108: ['kirk',
#   'enjoying',
#   'annual',
#   'christmas',
#   'party',
#   'extravaganza',
#   'thrown',
#   'sister',
#   'realizes',
#   'needs',
#   'help',
#   'christian',
#   'brotherinlaw',
#   'bad',
#   'case',
#   'bahhumbugs'],
#  109: ['group',
#   'smarttalking',
#   'toddlers',
#   'find',
#   'center',
#   'media',
#   'moguls',
#   'experiment',
#   'crack',
#   'code',
#   'baby',
#   'talk',
#   'toddlers',
#   'must',
#   'race',
#   'time',
#   'sake',
#   'babies',
#   'everywhere'],
#  110: ['evil',
#   'assassins',
#   'want',
#   'kill',
#   'daniel',
#   'kublbock',
#   'third',
#   'runner',
#   'german',
#   'idols'],
#  111: ['family',
#   'gets',
#   'lost',
#   'road',
#   'stumbles',
#   'upon',
#   'hidden',
#   'underground',
#   'devilworshiping',
#   'cult',
#   'led',
#   'fearsome',
#   'master',
#   'servant',
#   'torgo'],
#  112: ['south',
#   'beach',
#   'university',
#   'beautiful',
#   'sorority',
#   'president',
#   'takes',
#   'group',
#   'unconventional',
#   'freshman',
#   'girls',
#   'seeking',
#   'acceptance',
#   'house'],
#  113: ['family', 'turks', 'try', 'adapt', 'life', 'new', 'solar', 'system'],
#  114: ['evil',
#   'brand',
#   'x',
#   'joins',
#   'supermarket',
#   'becomes',
#   'city',
#   'closing',
#   'time'],
#  115: ['horde',
#   'mutated',
#   'birds',
#   'descends',
#   'upon',
#   'quiet',
#   'town',
#   'half',
#   'moon',
#   'bay',
#   'california',
#   'death',
#   'toll',
#   'rising',
#   'two',
#   'citizens',
#   'manage',
#   'fight',
#   'back',
#   'survive',
#   'birdemic'],
#  116: ['regina',
#   'popular',
#   'girl',
#   'make',
#   'new',
#   'friends',
#   'new',
#   'conservative',
#   'school',
#   'problems',
#   'arrive',
#   'becomes',
#   'enemies',
#   'lívia',
#   'schools',
#   'queen',
#   'bee',
#   'falls',
#   'love'],
#  117: ['cinderella',
#   'meets',
#   'prince',
#   'charming',
#   'illfated',
#   'titanic',
#   'along',
#   'ride',
#   'rapping',
#   'dog',
#   'talking',
#   'animals',
#   'assortment',
#   'wacky',
#   'humans'],
#  118: ['course',
#   'one',
#   'evening',
#   'unsuspecting',
#   'group',
#   'twentysomethings',
#   'find',
#   'bombarded',
#   'series',
#   'natural',
#   'disasters',
#   'catastrophic',
#   'events'],
#  119: ['psychotic',
#   'police',
#   'officer',
#   'murders',
#   'female',
#   'arrests',
#   'gets',
#   'whats',
#   'coming',
#   'horde',
#   'zombified',
#   'women',
#   'rise',
#   'graves',
#   'seek',
#   'revenge'],
#  120: ['woman',
#   'agrees',
#   'go',
#   'date',
#   'man',
#   'finds',
#   'suitor',
#   'unattractive',
#   'best',
#   'friend'],
#  121: ['kelogan', 'fights', 'black', 'prince', 'serve', 'justice'],
#  122: ['waitress',
#   'texas',
#   'college',
#   'student',
#   'pennsylvania',
#   'meet',
#   'spring',
#   'break',
#   'fort',
#   'lauderdale',
#   'florida',
#   'come',
#   'together',
#   'shared',
#   'love',
#   'singing'],
#  123: ['little',
#   'jack',
#   'young',
#   'fox',
#   'living',
#   'happily',
#   'family',
#   'woods',
#   'everything',
#   'changes',
#   'father',
#   'captured',
#   'circus',
#   'troupe',
#   'order',
#   'part',
#   'show',
#   'rest'],
#  124: ['nasikbased',
#   'heerendra',
#   'dhaan',
#   'raj',
#   'ranade',
#   'bodyguards',
#   'politician',
#   'employer',
#   'implicated',
#   'scam',
#   'end',
#   'assaulting',
#   'police',
#   'officer',
#   'flee',
#   'mumbai'],
#  125: ['struggling',
#   'young',
#   'comedian',
#   'takes',
#   'menial',
#   'job',
#   'cruise',
#   'ship',
#   'hopes',
#   'big',
#   'chance',
#   'make',
#   'world',
#   'cruise',
#   'ship',
#   'comedy'],
#  126: ['soldiers',
#   'want',
#   'commander',
#   'soldiers',
#   'always',
#   'hanging',
#   'around',
#   'commanders',
#   'want',
#   'bring',
#   'hell',
#   'soldiers',
#   'always',
#   'makes',
#   'jokes',
#   'palters',
#   'meanwhile',
#   'one',
#   'soldiers',
#   'deal',
#   'lover'],
#  127: ['oil',
#   'company',
#   'unwittingly',
#   'unleashes',
#   'prehistoric',
#   'shark',
#   'icy',
#   'prison',
#   'jurassic',
#   'killer',
#   'maroons',
#   'group',
#   'thieves',
#   'beautiful',
#   'young',
#   'female',
#   'college',
#   'students',
#   'abandoned'],
#  128: ['deadly',
#   'zombie',
#   'virus',
#   'infects',
#   'school',
#   'germany',
#   'remains',
#   'student',
#   'leo',
#   'save',
#   'world'],
#  129: ['pair',
#   'recently',
#   'married',
#   'gay',
#   'men',
#   'threatened',
#   'one',
#   'partners',
#   'brother',
#   'religious',
#   'fanatic',
#   'plots',
#   'murder',
#   'ostracized',
#   'church'],
#  130: ['grandfather',
#   'mouse',
#   'tells',
#   'grandchildren',
#   'real',
#   'story',
#   'titanic',
#   'disaster',
#   'including',
#   'evil',
#   'sharks',
#   'giant',
#   'octopus',
#   'evil',
#   'whaling',
#   'scheme'],
#  131: ['temple',
#   'priest',
#   'commits',
#   'suicide',
#   'dishonored',
#   'evil',
#   'landlord',
#   'son',
#   'returns',
#   'native',
#   'village',
#   'mission',
#   'vengeance'],
#  132: ['platoon',
#   'eagles',
#   'vultures',
#   'attack',
#   'hollywood',
#   'california',
#   'eagles',
#   'vultures',
#   'attack',
#   'survive'],
#  133: ['space',
#   'capsule',
#   'crashlands',
#   'earth',
#   'astronaut',
#   'aboard',
#   'disappears',
#   'connection',
#   'missing',
#   'man',
#   'monster',
#   'roaming',
#   'area'],
#  134: ['group',
#   'college',
#   'students',
#   'travel',
#   'mysterious',
#   'island',
#   'attend',
#   'rave',
#   'soon',
#   'taken',
#   'bloodthirsty',
#   'zombies'],
#  135: ['rap',
#   'mogul',
#   'atlanta',
#   'tries',
#   'join',
#   'conservative',
#   'country',
#   'club',
#   'carolinas',
#   'runs',
#   'fierce',
#   'opposition',
#   'board',
#   'president',
#   'nothing',
#   'entourage',
#   'cant',
#   'handle'],
#  136: ['comedy',
#   'centered',
#   'around',
#   'three',
#   'people',
#   'lookalike',
#   'lookalike',
#   'name'],
#  137: ['young',
#   'security',
#   'guard',
#   'must',
#   'track',
#   'diminutive',
#   'aliens',
#   'kill',
#   'people',
#   'even',
#   'make',
#   'fantasies',
#   'come',
#   'true'],
#  138: ['young',
#   'singer',
#   'dates',
#   'disc',
#   'jockey',
#   'helps',
#   'get',
#   'music',
#   'business',
#   'relationship',
#   'become',
#   'complicated',
#   'ascends',
#   'super',
#   'stardom'],
#  139: ['defecting',
#   'soviet',
#   'scientist',
#   'hit',
#   'nuclear',
#   'explosion',
#   'near',
#   'yucca',
#   'flats',
#   'roams',
#   'around',
#   'beast'],
#  140: ['tim',
#   'avery',
#   'aspiring',
#   'cartoonist',
#   'finds',
#   'predicament',
#   'dog',
#   'stumbles',
#   'upon',
#   'mask',
#   'loki',
#   'conceiving',
#   'infant',
#   'son',
#   'born',
#   'mask',
#   'discovers',
#   'looney',
#   'child',
#   'raising'],
#  141: ['naturally',
#   'talented',
#   'basketball',
#   'player',
#   'noah',
#   'cruise',
#   'determined',
#   'become',
#   'doctor',
#   'using',
#   'basketball',
#   'scholarship',
#   'ucla',
#   'premed',
#   'rather',
#   'succumb',
#   'lure',
#   'former',
#   'sports',
#   'agent'],
#  142: ['pilot',
#   'hope',
#   'stop',
#   'mutiny',
#   'spacecraft',
#   'security',
#   'crew',
#   'plot',
#   'sell',
#   'crew',
#   'ship',
#   'slavery'],
#  143: ['escaped',
#   'convict',
#   'griffin',
#   'friends',
#   'ran',
#   'way',
#   'hellwith',
#   'penny',
#   'broken',
#   'cigarette'],
#  144: ['young', 'boy', 'woods', 'discovers', 'lovable', 'alienor'],
#  145: ['count', 'dracula', 'terrorizes', 'crew', 'spaceship'],
#  146: ['pointlessly',
#   'named',
#   'batwoman',
#   'bevy',
#   'batmaidens',
#   'fight',
#   'evil',
#   'dance'],
#  147: ['ragtag',
#   'bunch',
#   'seniors',
#   'complete',
#   'outsiders',
#   'surfcrazed',
#   'laguna',
#   'beach',
#   'high',
#   'school',
#   'decide',
#   'crash',
#   'biggest',
#   'team',
#   'surf',
#   'contest',
#   'order',
#   'prevail',
#   'however',
#   'must',
#   'one'],
#  148: ['comedic',
#   'satire',
#   'films',
#   'large',
#   'scope',
#   'reputation',
#   'popularity'],
#  149: ['based',
#   'video',
#   'game',
#   'alone',
#   'dark',
#   'focuses',
#   'edward',
#   'carnby',
#   'detective',
#   'paranormal',
#   'slowly',
#   'unravels',
#   'mysterious',
#   'events',
#   'deadly',
#   'results'],
#  150: ['young',
#   'air',
#   'force',
#   'lieutenant',
#   'falls',
#   'love',
#   'fighter',
#   'planes',
#   'father',
#   'congressman',
#   'war',
#   'hero',
#   'yearns',
#   'fly',
#   'heavy',
#   'bombers'],
#  151: ['secret',
#   'agent',
#   'called',
#   'retirement',
#   'save',
#   'world',
#   'evil',
#   'genius'],
#  152: ['homicidal',
#   'sheriff',
#   'thomas',
#   'jefferson',
#   'geronimo',
#   'tasked',
#   'escorting',
#   'mobster',
#   'malta',
#   'prisoner',
#   'escapes',
#   'geronimo',
#   'goes',
#   'rogue',
#   'catch'],
#  153: ['teenagers',
#   'stumble',
#   'across',
#   'prehistoric',
#   'caveman',
#   'goes',
#   'rampage'],
#  154: ['modernday',
#   'updating',
#   'dracula',
#   'legend',
#   'finds',
#   'steven',
#   'goodlooking',
#   'american',
#   'hero',
#   'devastated',
#   'death',
#   'girlfriend',
#   'wandering',
#   'europe',
#   'looking',
#   'happiness'],
#  155: ['class',
#   'teenage',
#   'students',
#   'attempting',
#   'save',
#   'unconventional',
#   'school',
#   'closure',
#   'one',
#   'highestgrossing',
#   'turkish',
#   'films'],
#  156: ['follows',
#   'passing',
#   'fifa',
#   'baton',
#   'three',
#   'association',
#   'presidents',
#   'jules',
#   'rimet',
#   'joao',
#   'havelange',
#   'sepp',
#   'blatter'],
#  157: ['violent',
#   'story',
#   'criminal',
#   'lesbian',
#   'toughguy',
#   'hitman',
#   'heart',
#   'gold',
#   'mentally',
#   'challenged',
#   'man',
#   'came',
#   'best',
#   'friends',
#   'hostage'],
#  158: ['porn',
#   'actor',
#   'uses',
#   'fellow',
#   'adult',
#   'movie',
#   'stars',
#   'creating',
#   'fake',
#   'traditional',
#   'family',
#   'order',
#   'impress',
#   'girlfriends',
#   'conservative',
#   'father'],
#  159: ['lowbudget',
#   'film',
#   'young',
#   'man',
#   'given',
#   'mystical',
#   'medallion',
#   'aztec',
#   'shaman',
#   'order',
#   'become',
#   'pumaempowered',
#   'champion',
#   'like',
#   'father',
#   'trying',
#   'initially',
#   'locate'],
#  160: ['enslavement',
#   'near',
#   'extermination',
#   'alien',
#   'race',
#   'year',
#   'humanity',
#   'begins',
#   'fight',
#   'back'],
#  161: ['costantino',
#   'daniele',
#   'two',
#   'friends',
#   'success',
#   'girls',
#   'wish',
#   'work',
#   'show',
#   'business',
#   'achieve',
#   'goal',
#   'meet',
#   'valeria',
#   'top',
#   'model'],
#  162: ['inspired',
#   'true',
#   'events',
#   'polish',
#   'air',
#   'force',
#   'tu',
#   'crash',
#   'smolensk',
#   'film',
#   'tells',
#   'fictional',
#   'story',
#   'crash',
#   'various',
#   'people',
#   'affected',
#   'tragedy',
#   'protagonist'],
#  163: ['young',
#   'man',
#   'transformed',
#   'hideous',
#   'moon',
#   'beast',
#   'due',
#   'meteor',
#   'fragment',
#   'lodged',
#   'body'],
#  164: ['anne',
#   'b',
#   'real',
#   'coming',
#   'age',
#   'story',
#   'young',
#   'female',
#   'rapper',
#   'finds',
#   'inspiration',
#   'reading',
#   'diary',
#   'anne',
#   'frank'],
#  165: ['clumsy',
#   'invaders',
#   'neptune',
#   'thwarted',
#   'hero',
#   'space',
#   'chief',
#   'nondescript',
#   'group',
#   'microshortwearing',
#   'japanese',
#   'kids'],
#  166: ['jerry',
#   'falls',
#   'love',
#   'stripper',
#   'meets',
#   'carnival',
#   'little',
#   'know',
#   'sister',
#   'gypsy',
#   'fortune',
#   'teller',
#   'whose',
#   'predictions',
#   'scoffed',
#   'earlier',
#   'gypsy',
#   'turns',
#   'zombie',
#   'goes',
#   'killing',
#   'spree'],
#  167: ['mad', 'scientist', 'transforms', 'aquatic', 'killer'],
#  168: ['woman',
#   'seeks',
#   'revenge',
#   'former',
#   'lover',
#   'owns',
#   'skydiving',
#   'business'],
#  169: ['young',
#   'woman',
#   'leaves',
#   'job',
#   'waitress',
#   'travels',
#   'los',
#   'angeles',
#   'strives',
#   'become',
#   'top',
#   'star',
#   'glamorous',
#   'world',
#   'gogo',
#   'dancing'],
#  170: ['oogieloves',
#   'goobie',
#   'zoozie',
#   'toofie',
#   'set',
#   'find',
#   'five',
#   'magical',
#   'balloons',
#   'make',
#   'good',
#   'friend',
#   'schluufys',
#   'surprise',
#   'birthday',
#   'party',
#   'extraspecial'],
#  171: ['surfer', 'becomes', 'head', 'major', 'company'],
#  172: ['jobe',
#   'resuscitated',
#   'jonathan',
#   'walker',
#   'wants',
#   'jobe',
#   'create',
#   'special',
#   'computer',
#   'chip',
#   'would',
#   'connect',
#   'computers',
#   'world',
#   'one',
#   'network',
#   'walker',
#   'would',
#   'control'],
#  173: ['fathers',
#   'psychic',
#   'abilities',
#   'put',
#   'test',
#   'two',
#   'daughters',
#   'trapped',
#   'inside',
#   'corn',
#   'maze',
#   'haunted',
#   'spirits',
#   'two',
#   'young',
#   'girls',
#   'disappeared',
#   'year',
#   'earlier'],
#  174: ['young', 'man', 'meets', 'farm', 'girl', 'actually', 'witch'],
#  175: ['scientist',
#   'hold',
#   'talking',
#   'superintelligent',
#   'babies',
#   'captive',
#   'things',
#   'take',
#   'turn',
#   'worse',
#   'mixup',
#   'occurs',
#   'baby',
#   'genius',
#   'twin'],
#  176: ['four',
#   'teenagers',
#   'killed',
#   'car',
#   'accident',
#   'two',
#   'teenagers',
#   'refuse',
#   'go',
#   'grim',
#   'reaper',
#   'race',
#   'life',
#   'death',
#   'ensues'],
#  177: ['musclebound',
#   'ator',
#   'mute',
#   'east',
#   'asian',
#   'sidekick',
#   'travel',
#   'ends',
#   'earth',
#   'save',
#   'aged',
#   'mentor',
#   'evil',
#   'mustachioed',
#   'zor'],
#  178: ['alien',
#   'force',
#   'tries',
#   'invade',
#   'earth',
#   'steal',
#   'powerful',
#   'new',
#   'rocket',
#   'fuel',
#   'mysterious',
#   'hero',
#   'intervenes'],
#  179: ['basketball',
#   'superstar',
#   'dennis',
#   'rodman',
#   'stars',
#   'hip',
#   'interpol',
#   'agent',
#   'attempting',
#   'defeat',
#   'deadly',
#   'plans',
#   'crazed',
#   'arms',
#   'dealer'],
#  180: ['martians',
#   'kidnap',
#   'santa',
#   'claus',
#   'nobody',
#   'mars',
#   'give',
#   'children',
#   'presents'],
#  181: ['posing',
#   'movie',
#   'producer',
#   'conman',
#   'attempts',
#   'trick',
#   'entire',
#   'village',
#   'helping',
#   'rob',
#   'treasureladen',
#   'train'],
#  182: ['comedic',
#   'spoof',
#   'based',
#   'worldwide',
#   'phenomenon',
#   'twilight',
#   'saga'],
#  183: ['evil',
#   'millionaire',
#   'believes',
#   'santa',
#   'claus',
#   'accident',
#   'renders',
#   'amnesiac'],
#  184: ['young',
#   'man',
#   'killed',
#   'gang',
#   'rampant',
#   'teenagers',
#   'resurrected',
#   'voodoo',
#   'priestess',
#   'avenge',
#   'death'],
#  185: ['professor',
#   'three',
#   'students',
#   'camp',
#   'wilderness',
#   'find',
#   'bigfoottype',
#   'creature'],
#  186: ['two',
#   'young',
#   'people',
#   'stand',
#   'street',
#   'corner',
#   'rundown',
#   'part',
#   'new',
#   'york',
#   'kissing',
#   'despite',
#   'lawlessness',
#   'district',
#   'left',
#   'unmolested',
#   'short',
#   'distance',
#   'away',
#   'walk',
#   'maria'],
#  187: ['fat', 'slags', 'viz', 'hit', 'big', 'time', 'become', 'celebrities'],
#  188: ['brash',
#   'nyc',
#   'policeman',
#   'officer',
#   'gunther',
#   'toody',
#   'partnered',
#   'stiff',
#   'bythebook',
#   'officer',
#   'francis',
#   'muldoon',
#   'protect',
#   'important',
#   'mafia',
#   'witness',
#   'prior',
#   'testifying',
#   'orgainzed',
#   'crime'],
#  189: ['young',
#   'warrior',
#   'son',
#   'goku',
#   'sets',
#   'quest',
#   'racing',
#   'time',
#   'vengeful',
#   'king',
#   'piccolo',
#   'collect',
#   'set',
#   'seven',
#   'magical',
#   'orbs',
#   'grant',
#   'wielder',
#   'unlimited',
#   'power'],
#  190: ['mad',
#   'doctor',
#   'builds',
#   'robot',
#   'order',
#   'steal',
#   'valuable',
#   'aztec',
#   'treasure',
#   'tomb',
#   'guarded',
#   'centuriesold',
#   'living',
#   'mummy'],
#  191: ['survivors',
#   'plane',
#   'crash',
#   'remote',
#   'island',
#   'find',
#   'covered',
#   'spiders',
#   'bitten',
#   'survivors',
#   'start',
#   'turning',
#   'spiders'],
#  192: ['sleazy',
#   'incompetent',
#   'detective',
#   'tries',
#   'simultaneously',
#   'take',
#   'heroin',
#   'dealers',
#   'socialite',
#   'murdered',
#   'burglar'],
#  193: ['alternate',
#   'futuristic',
#   'society',
#   'tough',
#   'female',
#   'police',
#   'detective',
#   'paired',
#   'talking',
#   'dinosaur',
#   'find',
#   'killer',
#   'dinosaurs',
#   'prehistoric',
#   'animals',
#   'leading',
#   'mad',
#   'scientist',
#   'bent',
#   'creating',
#   'new',
#   'armageddon'],
#  194: ['aid',
#   'merlin',
#   'santa',
#   'claus',
#   'must',
#   'defeat',
#   'evil',
#   'machinations',
#   'devil',
#   'pitch',
#   'ruin',
#   'xmas'],
#  195: ['teenager',
#   'stumbles',
#   'upon',
#   'alien',
#   'weapon',
#   'transforms',
#   'grotesque',
#   'killer'],
#  196: ['trained',
#   'chimpanzee',
#   'plays',
#   'third',
#   'base',
#   'minorleague',
#   'baseball',
#   'team'],
#  197: ['teens',
#   'trapped',
#   'island',
#   'haunted',
#   'demon',
#   'hidden',
#   'insidea',
#   'pinata'],
#  198: ['inventor',
#   'comes',
#   'time',
#   'machine',
#   'must',
#   'prevent',
#   'abuse',
#   'hands',
#   'evil',
#   'ceo'],
#  199: ['marine',
#   'biologist',
#   'dolphin',
#   'trainer',
#   'research',
#   'scientist',
#   'local',
#   'sheriff',
#   'try',
#   'hunt',
#   'large',
#   'sea',
#   'monster',
#   'sharkoctopus',
#   'hybrid',
#   'devouring',
#   'swimmers',
#   'fishermen',
#   'south',
#   'florida',
#   'coast'],
#  200: ['heroic',
#   'spartan',
#   'king',
#   'leonidas',
#   'armed',
#   'nothing',
#   'leather',
#   'underwear',
#   'cape',
#   'leads',
#   'ragtag',
#   'bunch',
#   'spartan',
#   'misfit',
#   'warriors',
#   'defend',
#   'homeland',
#   'thousands'],
#  201: ['comedic', 'misadventures', 'person', 'indeterminate', 'gender'],
#  202: ['young',
#   'man',
#   'goes',
#   'work',
#   'gangsters',
#   'impress',
#   'nightclubsinger',
#   'girlfriend'],
#  203: ['bitten',
#   'bat',
#   'cave',
#   'doctor',
#   'undergoes',
#   'accelerating',
#   'transformation',
#   'manbat',
#   'ruins',
#   'vacation',
#   'causes',
#   'considerable',
#   'distress',
#   'wife'],
#  204: ['two', 'comedians', 'set', 'make', 'exploitation', 'video'],
#  205: ['elderly',
#   'scott',
#   'kills',
#   'heart',
#   'attack',
#   'wrecks',
#   'body',
#   'comes',
#   'back',
#   'ghost',
#   'convinces',
#   'loving',
#   'young',
#   'hot',
#   'wife',
#   'kate',
#   'pick',
#   'kill',
#   'young',
#   'man',
#   'order',
#   'scott',
#   'possess',
#   'body'],
#  206: ['nomad',
#   'mercenary',
#   'hightech',
#   'motorcycle',
#   'helps',
#   'bring',
#   'downfall',
#   'evil',
#   'orwellian',
#   'government',
#   'omega'],
#  207: ['two',
#   'imprisoned',
#   'men',
#   'bond',
#   'number',
#   'years',
#   'finding',
#   'solace',
#   'eventual',
#   'redemption',
#   'acts',
#   'common',
#   'decency'],
#  208: ['aging',
#   'patriarch',
#   'organized',
#   'crime',
#   'dynasty',
#   'transfers',
#   'control',
#   'clandestine',
#   'empire',
#   'reluctant',
#   'son'],
#  209: ['early',
#   'life',
#   'career',
#   'vito',
#   'corleone',
#   'new',
#   'york',
#   'portrayed',
#   'son',
#   'michael',
#   'expands',
#   'tightens',
#   'grip',
#   'family',
#   'crime',
#   'syndicate'],
#  210: ['menace',
#   'known',
#   'joker',
#   'emerges',
#   'mysterious',
#   'past',
#   'wreaks',
#   'havoc',
#   'chaos',
#   'people',
#   'gotham',
#   'dark',
#   'knight',
#   'must',
#   'accept',
#   'one',
#   'greatest',
#   'psychological',
#   'physical',
#   'tests',
#   'ability',
#   'fight',
#   'injustice'],
#  211: ['jury',
#   'holdout',
#   'attempts',
#   'prevent',
#   'miscarriage',
#   'justice',
#   'forcing',
#   'colleagues',
#   'reconsider',
#   'evidence'],
#  212: ['germanoccupied',
#   'poland',
#   'world',
#   'war',
#   'ii',
#   'oskar',
#   'schindler',
#   'gradually',
#   'becomes',
#   'concerned',
#   'jewish',
#   'workforce',
#   'witnessing',
#   'persecution',
#   'nazi',
#   'germans'],
#  213: ['gandalf',
#   'aragorn',
#   'lead',
#   'world',
#   'men',
#   'saurons',
#   'army',
#   'draw',
#   'gaze',
#   'frodo',
#   'sam',
#   'approach',
#   'mount',
#   'doom',
#   'one',
#   'ring'],
#  214: ['lives',
#   'two',
#   'mob',
#   'hit',
#   'men',
#   'boxer',
#   'gangsters',
#   'wife',
#   'pair',
#   'diner',
#   'bandits',
#   'intertwine',
#   'four',
#   'tales',
#   'violence',
#   'redemption'],
#  215: ['insomniac',
#   'office',
#   'worker',
#   'looking',
#   'way',
#   'change',
#   'life',
#   'crosses',
#   'paths',
#   'devilmaycare',
#   'soap',
#   'maker',
#   'forming',
#   'underground',
#   'fight',
#   'club',
#   'evolves',
#   'something',
#   'much',
#   'much'],
#  216: ['meek',
#   'hobbit',
#   'shire',
#   'eight',
#   'companions',
#   'set',
#   'journey',
#   'destroy',
#   'powerful',
#   'one',
#   'ring',
#   'save',
#   'middle',
#   'earth',
#   'dark',
#   'lord',
#   'sauron'],
#  217: ['intelligent',
#   'forrest',
#   'gump',
#   'accidentally',
#   'present',
#   'many',
#   'historic',
#   'moments',
#   'true',
#   'love',
#   'jenny',
#   'curran',
#   'eludes'],
#  218: ['rebels',
#   'overpowered',
#   'empire',
#   'newly',
#   'established',
#   'base',
#   'luke',
#   'skywalker',
#   'begins',
#   'jedi',
#   'training',
#   'master',
#   'yoda',
#   'friends',
#   'accept',
#   'shelter',
#   'questionable',
#   'ally',
#   'darth',
#   'vader',
#   'hunts',
#   'plan',
#   'capture',
#   'luke'],
#  219: ['thief',
#   'steals',
#   'corporate',
#   'secrets',
#   'use',
#   'dreamsharing',
#   'technology',
#   'given',
#   'inverse',
#   'task',
#   'planting',
#   'idea',
#   'mind',
#   'ceo'],
#  220: ['frodo',
#   'sam',
#   'edge',
#   'closer',
#   'mordor',
#   'help',
#   'shifty',
#   'gollum',
#   'divided',
#   'fellowship',
#   'makes',
#   'stand',
#   'saurons',
#   'new',
#   'ally',
#   'saruman',
#   'hordes',
#   'isengard'],
#  221: ['criminal',
#   'pleads',
#   'insanity',
#   'getting',
#   'trouble',
#   'mental',
#   'institution',
#   'rebels',
#   'oppressive',
#   'nurse',
#   'rallies',
#   'scared',
#   'patients'],
#  222: ['story',
#   'henry',
#   'hill',
#   'life',
#   'teen',
#   'years',
#   'years',
#   'mafia',
#   'covering',
#   'relationship',
#   'wife',
#   'karen',
#   'hill',
#   'mob',
#   'partners',
#   'jimmy',
#   'conway',
#   'tommy',
#   'devitto',
#   'italianamerican',
#   'crime',
#   'syndicate'],
#  223: ['computer',
#   'hacker',
#   'learns',
#   'mysterious',
#   'rebels',
#   'true',
#   'nature',
#   'reality',
#   'role',
#   'war',
#   'controllers'],
#  224: ['luke',
#   'skywalker',
#   'joins',
#   'forces',
#   'jedi',
#   'knight',
#   'cocky',
#   'pilot',
#   'wookiee',
#   'two',
#   'droids',
#   'save',
#   'galaxy',
#   'empires',
#   'worlddestroying',
#   'battlestation',
#   'also',
#   'attempting',
#   'rescue',
#   'princess',
#   'leia',
#   'evil',
#   'darth',
#   'vader'],
#  225: ['two',
#   'detectives',
#   'rookie',
#   'veteran',
#   'hunt',
#   'serial',
#   'killer',
#   'uses',
#   'seven',
#   'deadly',
#   'sins',
#   'motives'],
#  226: ['angel',
#   'sent',
#   'heaven',
#   'help',
#   'desperately',
#   'frustrated',
#   'businessman',
#   'showing',
#   'life',
#   'would',
#   'like',
#   'never',
#   'existed'],
#  227: ['young',
#   'fbi',
#   'cadet',
#   'must',
#   'confide',
#   'incarcerated',
#   'manipulative',
#   'killer',
#   'receive',
#   'help',
#   'catching',
#   'another',
#   'serial',
#   'killer',
#   'skins',
#   'victims'],
#  228: ['sole',
#   'survivor',
#   'tells',
#   'twisty',
#   'events',
#   'leading',
#   'horrific',
#   'gun',
#   'battle',
#   'boat',
#   'began',
#   'five',
#   'criminals',
#   'met',
#   'seemingly',
#   'random',
#   'police',
#   'lineup'],
#  229: ['mathilda',
#   'yearold',
#   'girl',
#   'reluctantly',
#   'taken',
#   'léon',
#   'professional',
#   'assassin',
#   'family',
#   'murdered',
#   'léon',
#   'mathilda',
#   'form',
#   'unusual',
#   'relationship',
#   'becomes',
#   'protégée',
#   'learns',
#   'assassins',
#   'trade'],
#  230: ['following',
#   'normandy',
#   'landings',
#   'group',
#   'us',
#   'soldiers',
#   'go',
#   'behind',
#   'enemy',
#   'lines',
#   'retrieve',
#   'paratrooper',
#   'whose',
#   'brothers',
#   'killed',
#   'action'],
#  231: ['aid',
#   'wealthy',
#   'erratic',
#   'tippler',
#   'dewyeyed',
#   'tramp',
#   'fallen',
#   'love',
#   'sightless',
#   'flower',
#   'girl',
#   'accumulates',
#   'money',
#   'able',
#   'help',
#   'medically'],
#  232: ['team',
#   'explorers',
#   'travel',
#   'wormhole',
#   'space',
#   'attempt',
#   'ensure',
#   'humanitys',
#   'survival'],
#  233: ['former',
#   'neonazi',
#   'skinhead',
#   'tries',
#   'prevent',
#   'younger',
#   'brother',
#   'going',
#   'wrong',
#   'path'],
#  234: ['tramp',
#   'struggles',
#   'live',
#   'modern',
#   'industrial',
#   'society',
#   'help',
#   'young',
#   'homeless',
#   'woman'],
#  235: ['casablanca',
#   'december',
#   'cynical',
#   'american',
#   'expatriate',
#   'encounters',
#   'former',
#   'lover',
#   'unforeseen',
#   'complications'],
#  236: ['lives',
#   'guards',
#   'death',
#   'row',
#   'affected',
#   'one',
#   'charges',
#   'black',
#   'man',
#   'accused',
#   'child',
#   'murder',
#   'rape',
#   'yet',
#   'mysterious',
#   'gift'],
#  237: ['phoenix',
#   'secretary',
#   'embezzles',
#   'employers',
#   'client',
#   'goes',
#   'run',
#   'checks',
#   'remote',
#   'motel',
#   'run',
#   'young',
#   'man',
#   'domination',
#   'mother'],
#  238: ['archaeologist',
#   'adventurer',
#   'indiana',
#   'jones',
#   'hired',
#   'us',
#   'government',
#   'find',
#   'ark',
#   'covenant',
#   'nazis'],
#  239: ['polish',
#   'jewish',
#   'musician',
#   'struggles',
#   'survive',
#   'destruction',
#   'warsaw',
#   'ghetto',
#   'world',
#   'war',
#   'ii'],
#  240: ['wheelchairbound',
#   'photographer',
#   'spies',
#   'neighbours',
#   'apartment',
#   'window',
#   'becomes',
#   'convinced',
#   'one',
#   'committed',
#   'murder'],
#  241: ['undercover',
#   'cop',
#   'mole',
#   'police',
#   'attempt',
#   'identify',
#   'infiltrating',
#   'irish',
#   'gang',
#   'south',
#   'boston'],
#  242: ['promising',
#   'young',
#   'drummer',
#   'enrolls',
#   'cutthroat',
#   'music',
#   'conservatory',
#   'dreams',
#   'greatness',
#   'mentored',
#   'instructor',
#   'stop',
#   'nothing',
#   'realize',
#   'students',
#   'potential'],
#  243: ['cyborg',
#   'identical',
#   'one',
#   'failed',
#   'kill',
#   'sarah',
#   'connor',
#   'must',
#   'protect',
#   'ten',
#   'year',
#   'old',
#   'son',
#   'john',
#   'connor',
#   'advanced',
#   'cyborg'],
#  244: ['marty',
#   'mcfly',
#   'yearold',
#   'high',
#   'school',
#   'student',
#   'accidentally',
#   'sent',
#   'years',
#   'past',
#   'timetraveling',
#   'delorean',
#   'invented',
#   'close',
#   'friend',
#   'maverick',
#   'scientist',
#   'doc',
#   'brown'],
#  245: ['roman',
#   'general',
#   'betrayed',
#   'family',
#   'murdered',
#   'emperors',
#   'corrupt',
#   'son',
#   'comes',
#   'rome',
#   'gladiator',
#   'seek',
#   'revenge'],
#  246: ['lion',
#   'cub',
#   'future',
#   'king',
#   'simba',
#   'searches',
#   'identity',
#   'eagerness',
#   'please',
#   'others',
#   'penchant',
#   'testing',
#   'boundaries',
#   'sometimes',
#   'gets',
#   'trouble'],
#  247: ['two',
#   'stage',
#   'magicians',
#   'engage',
#   'competitive',
#   'oneupmanship',
#   'attempt',
#   'create',
#   'ultimate',
#   'stage',
#   'illusion'],
#  248: ['vietnam',
#   'war',
#   'captain',
#   'willard',
#   'sent',
#   'dangerous',
#   'mission',
#   'cambodia',
#   'assassinate',
#   'renegade',
#   'colonel',
#   'set',
#   'god',
#   'among',
#   'local',
#   'tribe'],
#  249: ['man',
#   'juggles',
#   'searching',
#   'wifes',
#   'murderer',
#   'keeping',
#   'shortterm',
#   'memory',
#   'loss',
#   'obstacle'],
#  250: ['dictator',
#   'adenoid',
#   'hynkel',
#   'tries',
#   'expand',
#   'empire',
#   'poor',
#   'jewish',
#   'barber',
#   'tries',
#   'avoid',
#   'persecution',
#   'hynkels',
#   'regime'],
#  251: ['screenwriter',
#   'hired',
#   'rework',
#   'faded',
#   'silent',
#   'film',
#   'stars',
#   'script',
#   'find',
#   'developing',
#   'dangerous',
#   'relationship'],
#  252: ['space',
#   'merchant',
#   'vessel',
#   'perceives',
#   'unknown',
#   'transmission',
#   'distress',
#   'call',
#   'landing',
#   'source',
#   'moon',
#   'finds',
#   'one',
#   'crew',
#   'attacked',
#   'mysterious',
#   'lifeform',
#   'soon',
#   'realize',
#   'life',
#   'cycle',
#   'merely',
#   'begun'],
#  253: ['insane',
#   'general',
#   'triggers',
#   'path',
#   'nuclear',
#   'holocaust',
#   'war',
#   'room',
#   'full',
#   'politicians',
#   'generals',
#   'frantically',
#   'try',
#   'stop'],
#  254: ['refusing',
#   'attack',
#   'enemy',
#   'position',
#   'general',
#   'accuses',
#   'soldiers',
#   'cowardice',
#   'commanding',
#   'officer',
#   'must',
#   'defend'],
#  255: ['help',
#   'german',
#   'bounty',
#   'hunter',
#   'freed',
#   'slave',
#   'sets',
#   'rescue',
#   'wife',
#   'brutal',
#   'mississippi',
#   'plantation',
#   'owner'],
#  256: ['family',
#   'heads',
#   'isolated',
#   'hotel',
#   'winter',
#   'evil',
#   'spiritual',
#   'presence',
#   'influences',
#   'father',
#   'violence',
#   'psychic',
#   'son',
#   'sees',
#   'horrific',
#   'forebodings',
#   'past',
#   'future'],
#  257: ['veteran',
#   'british',
#   'barrister',
#   'must',
#   'defend',
#   'client',
#   'murder',
#   'trial',
#   'surprise',
#   'surprise'],
#  258: ['eight',
#   'years',
#   'jokers',
#   'reign',
#   'anarchy',
#   'dark',
#   'knight',
#   'help',
#   'enigmatic',
#   'selina',
#   'forced',
#   'imposed',
#   'exile',
#   'save',
#   'gotham',
#   'city',
#   'edge',
#   'total',
#   'annihilation',
#   'brutal',
#   'guerrilla',
#   'terrorist',
#   'bane'],
#  259: ['distant',
#   'future',
#   'small',
#   'wastecollecting',
#   'robot',
#   'inadvertently',
#   'embarks',
#   'space',
#   'journey',
#   'ultimately',
#   'decide',
#   'fate',
#   'mankind'],
#  260: ['sexually',
#   'frustrated',
#   'suburban',
#   'father',
#   'midlife',
#   'crisis',
#   'becoming',
#   'infatuated',
#   'daughters',
#   'best',
#   'friend'],
#  261: ['former',
#   'prohibitionera',
#   'jewish',
#   'gangster',
#   'returns',
#   'lower',
#   'east',
#   'side',
#   'manhattan',
#   'thirty',
#   'years',
#   'later',
#   'must',
#   'confront',
#   'ghosts',
#   'regrets',
#   'old',
#   'life'],
#  262: ['moon',
#   'alien',
#   'colonized',
#   'contact',
#   'lost',
#   'time',
#   'rescue',
#   'team',
#   'impressive',
#   'firepower',
#   'enough'],
#  263: ['following',
#   'death',
#   'publishing',
#   'tycoon',
#   'news',
#   'reporters',
#   'scramble',
#   'discover',
#   'meaning',
#   'final',
#   'utterance'],
#  264: ['hapless',
#   'new',
#   'york',
#   'advertising',
#   'executive',
#   'mistaken',
#   'government',
#   'agent',
#   'group',
#   'foreign',
#   'spies',
#   'pursued',
#   'across',
#   'country',
#   'looks',
#   'way',
#   'survive'],
#  265: ['san',
#   'francisco',
#   'detective',
#   'suffering',
#   'acrophobia',
#   'investigates',
#   'strange',
#   'activities',
#   'old',
#   'friends',
#   'wife',
#   'becoming',
#   'dangerously',
#   'obsessed'],
#  266: ['daring',
#   'mission',
#   'rescue',
#   'han',
#   'solo',
#   'jabba',
#   'hutt',
#   'rebels',
#   'dispatch',
#   'endor',
#   'destroy',
#   'powerful',
#   'death',
#   'star',
#   'meanwhile',
#   'luke',
#   'struggles',
# ...
#   'banner',
#   'scientist',
#   'run',
#   'us',
#   'government',
#   'must',
#   'find',
#   'cure',
#   'monster',
#   'emerges',
#   'whenever',
#   'loses',
#   'temper'],
#  921: ['bruce',
#   'banner',
#   'genetics',
#   'researcher',
#   'tragic',
#   'past',
#   'suffers',
#   'accident',
#   'causes',
#   'transform',
#   'raging',
#   'green',
#   'monster',
#   'gets',
#   'angry'],
#  922: ['scientist',
#   'makes',
#   'last',
#   'stand',
#   'earth',
#   'help',
#   'ragtag',
#   'team',
#   'soldiers',
#   'invasion',
#   'alien',
#   'phantoms'],
#  923: ['birth',
#   'renesmee',
#   'cullens',
#   'gather',
#   'vampire',
#   'clans',
#   'order',
#   'protect',
#   'child',
#   'false',
#   'allegation',
#   'puts',
#   'family',
#   'front',
#   'volturi'],
#  924: ['cave',
#   'destroyed',
#   'caveman',
#   'family',
#   'must',
#   'trek',
#   'unfamiliar',
#   'fantastical',
#   'world',
#   'help',
#   'inventive',
#   'boy'],
#  925: ['james',
#   'bond',
#   'uncovers',
#   'nuclear',
#   'plot',
#   'protects',
#   'oil',
#   'heiress',
#   'former',
#   'kidnapper',
#   'international',
#   'terrorist',
#   'cant',
#   'feel',
#   'pain'],
#  926: ['rango',
#   'ordinary',
#   'chameleon',
#   'accidentally',
#   'winds',
#   'town',
#   'dirt',
#   'lawless',
#   'outpost',
#   'wild',
#   'west',
#   'desperate',
#   'need',
#   'new',
#   'sheriff'],
#  927: ['napoleonic',
#   'wars',
#   'brash',
#   'british',
#   'captain',
#   'pushes',
#   'ship',
#   'crew',
#   'limits',
#   'pursuit',
#   'formidable',
#   'french',
#   'war',
#   'vessel',
#   'around',
#   'south',
#   'america'],
#  928: ['freak',
#   'accident',
#   'might',
#   'help',
#   'everyday',
#   'garden',
#   'snail',
#   'achieve',
#   'biggest',
#   'dream',
#   'winning',
#   'indy'],
#  929: ['facing',
#   'shredder',
#   'joined',
#   'forces',
#   'mad',
#   'scientist',
#   'baxter',
#   'stockman',
#   'henchmen',
#   'bebop',
#   'rocksteady',
#   'take',
#   'world',
#   'turtles',
#   'must',
#   'confront',
#   'even',
#   'greater',
#   'nemesis',
#   'notorious',
#   'krang'],
#  930: ['mumbles',
#   'son',
#   'erik',
#   'struggling',
#   'realize',
#   'talents',
#   'emperor',
#   'penguin',
#   'world',
#   'meanwhile',
#   'mumble',
#   'family',
#   'friends',
#   'discover',
#   'new',
#   'threat',
#   'home',
#   'one',
#   'take',
#   'everyone',
#   'working',
#   'together',
#   'save'],
#  931: ['earth',
#   'invaded',
#   'alien',
#   'tripod',
#   'fighting',
#   'machines',
#   'one',
#   'family',
#   'fights',
#   'survival'],
#  932: ['skipper',
#   'kowalski',
#   'rico',
#   'private',
#   'join',
#   'forces',
#   'undercover',
#   'organization',
#   'north',
#   'wind',
#   'stop',
#   'villainous',
#   'dr',
#   'octavius',
#   'brine',
#   'destroying',
#   'world',
#   'know'],
#  933: ['katniss',
#   'everdeen',
#   'peeta',
#   'mellark',
#   'become',
#   'targets',
#   'capitol',
#   'victory',
#   'th',
#   'hunger',
#   'games',
#   'sparks',
#   'rebellion',
#   'districts',
#   'panem'],
#  934: ['harrys',
#   'third',
#   'year',
#   'hogwarts',
#   'new',
#   'defense',
#   'dark',
#   'arts',
#   'teacher',
#   'also',
#   'trouble',
#   'brewing',
#   'convicted',
#   'murderer',
#   'sirius',
#   'black',
#   'escaped',
#   'wizards',
#   'prison',
#   'coming',
#   'harry'],
#  935: ['dragon',
#   'warrior',
#   'clash',
#   'savage',
#   'tai',
#   'lung',
#   'chinas',
#   'fate',
#   'hangs',
#   'balance',
#   'however',
#   'dragon',
#   'warrior',
#   'mantle',
#   'supposedly',
#   'mistaken',
#   'bestowed',
#   'upon',
#   'obese',
#   'panda',
#   'tyro',
#   'martial',
#   'arts'],
#  936: ['armed',
#   'supersuit',
#   'astonishing',
#   'ability',
#   'shrink',
#   'scale',
#   'increase',
#   'strength',
#   'cat',
#   'burglar',
#   'scott',
#   'lang',
#   'must',
#   'embrace',
#   'inner',
#   'hero',
#   'help',
#   'mentor',
#   'dr',
#   'hank',
#   'pym',
#   'plan',
#   'pull',
#   'heist',
#   'save',
#   'world'],
#  937: ['alien',
#   'run',
#   'people',
#   'makes',
#   'friends',
#   'girl',
#   'tries',
#   'help',
#   'quest',
#   'interference'],
#  938: ['outlaw',
#   'cat',
#   'childhood',
#   'eggfriend',
#   'seductive',
#   'thief',
#   'kitty',
#   'set',
#   'search',
#   'eggs',
#   'fabled',
#   'golden',
#   'goose',
#   'clear',
#   'name',
#   'restore',
#   'lost',
#   'honor',
#   'regain',
#   'trust',
#   'mother',
#   'town'],
#  939: ['supervillain',
#   'megamind',
#   'finally',
#   'defeats',
#   'nemesis',
#   'superhero',
#   'metro',
#   'man',
#   'without',
#   'hero',
#   'loses',
#   'purpose',
#   'must',
#   'find',
#   'new',
#   'meaning',
#   'life'],
#  940: ['two',
#   'loosecannon',
#   'narcotics',
#   'cops',
#   'investigate',
#   'flow',
#   'ecstasy',
#   'florida',
#   'cuban',
#   'drug',
#   'cartel'],
#  941: ['jungle',
#   'blu',
#   'jewel',
#   'three',
#   'kids',
#   'theyre',
#   'hurtled',
#   'rio',
#   'de',
#   'janeiro',
#   'wilds',
#   'amazon',
#   'blu',
#   'tries',
#   'fit',
#   'goes',
#   'beaktobeak',
#   'vengeful',
#   'nigel',
#   'meets',
#   'fatherinlaw'],
#  942: ['cia', 'agent', 'goes', 'run', 'defector', 'accuses', 'russian', 'spy'],
#  943: ['man',
#   'chosen',
#   'worlds',
#   'creator',
#   'undertake',
#   'momentous',
#   'mission',
#   'apocalyptic',
#   'flood',
#   'cleanses',
#   'world'],
#  944: ['intrepid',
#   'reporter',
#   'tintin',
#   'captain',
#   'haddock',
#   'set',
#   'treasure',
#   'hunt',
#   'sunken',
#   'ship',
#   'commanded',
#   'haddocks',
#   'ancestor'],
#  945: ['crash',
#   'landing',
#   'leaves',
#   'kitai',
#   'raige',
#   'father',
#   'cypher',
#   'stranded',
#   'earth',
#   'millennium',
#   'events',
#   'forced',
#   'humanitys',
#   'escape',
#   'cypher',
#   'injured',
#   'kitai',
#   'must',
#   'embark',
#   'perilous',
#   'journey',
#   'signal',
#   'help'],
#  946: ['set',
#   'northern',
#   'australia',
#   'world',
#   'war',
#   'ii',
#   'english',
#   'aristocrat',
#   'inherits',
#   'sprawling',
#   'ranch',
#   'reluctantly',
#   'pacts',
#   'stockman',
#   'order',
#   'protect',
#   'new',
#   'property',
#   'takeover',
#   'plot',
#   'pair',
#   'drive',
#   'head',
#   'cattle',
#   'unforgiving',
#   'landscape',
#   'experience',
#   'bombing',
#   'darwin',
#   'australia',
#   'japanese',
#   'forces',
#   'firsthand'],
#  947: ['recently',
#   'slain',
#   'cop',
#   'joins',
#   'team',
#   'undead',
#   'police',
#   'officers',
#   'working',
#   'rest',
#   'peace',
#   'department',
#   'tries',
#   'find',
#   'man',
#   'murdered'],
#  948: ['orphaned',
#   'dinosaur',
#   'raised',
#   'lemurs',
#   'joins',
#   'arduous',
#   'trek',
#   'sancturary',
#   'meteorite',
#   'shower',
#   'destroys',
#   'family',
#   'home'],
#  949: ['larry',
#   'spans',
#   'globe',
#   'uniting',
#   'favorite',
#   'new',
#   'characters',
#   'embarking',
#   'epic',
#   'quest',
#   'save',
#   'magic',
#   'gone',
#   'forever'],
#  950: ['harry',
#   'ron',
#   'hermione',
#   'must',
#   'destroy',
#   'last',
#   'horcruxes',
#   'kill',
#   'voldemort'],
#  951: ['katniss',
#   'everdeen',
#   'district',
#   'shatters',
#   'games',
#   'forever',
#   'leadership',
#   'president',
#   'coin',
#   'advice',
#   'trusted',
#   'friends',
#   'katniss',
#   'spreads',
#   'wings',
#   'fights',
#   'save',
#   'peeta',
#   'nation',
#   'moved',
#   'courage'],
#  952: ['rescued',
#   'outrageous',
#   'neglect',
#   'aunt',
#   'uncle',
#   'young',
#   'boy',
#   'great',
#   'destiny',
#   'proves',
#   'worth',
#   'attending',
#   'hogwarts',
#   'school',
#   'witchcraft',
#   'wizardry'],
#  953: ['harryronand', 'hermione', 'search', 'horcruxes', 'fight', 'theres'],
#  954: ['murder',
#   'inside',
#   'louvre',
#   'clues',
#   'da',
#   'vinci',
#   'paintings',
#   'lead',
#   'discovery',
#   'religious',
#   'mystery',
#   'protected',
#   'secret',
#   'society',
#   'two',
#   'thousand',
#   'years',
#   'could',
#   'shake',
#   'foundations',
#   'christianity'],
#  955: ['xmen',
#   'band',
#   'together',
#   'find',
#   'mutant',
#   'assassin',
#   'made',
#   'attempt',
#   'presidents',
#   'life',
#   'mutant',
#   'academy',
#   'attacked',
#   'military',
#   'forces'],
#  956: ['dominic',
#   'toretto',
#   'crew',
#   'street',
#   'racers',
#   'plan',
#   'massive',
#   'heist',
#   'buy',
#   'freedom',
#   'sights',
#   'powerful',
#   'brazilian',
#   'drug',
#   'lord',
#   'dangerous',
#   'federal',
#   'agent'],
#  957: ['kingpin',
#   'threatens',
#   'new',
#   'york',
#   'city',
#   'group',
#   'mutated',
#   'turtle',
#   'warriors',
#   'must',
#   'emerge',
#   'shadows',
#   'protect',
#   'home'],
#  958: ['sherlock',
#   'holmes',
#   'sidekick',
#   'dr',
#   'watson',
#   'join',
#   'forces',
#   'outwit',
#   'bring',
#   'fiercest',
#   'adversary',
#   'professor',
#   'moriarty'],
#  959: ['jack',
#   'hall',
#   'paleoclimatologist',
#   'must',
#   'make',
#   'daring',
#   'trek',
#   'across',
#   'america',
#   'reach',
#   'son',
#   'trapped',
#   'crosshairs',
#   'sudden',
#   'international',
#   'storm',
#   'plunges',
#   'planet',
#   'new',
#   'ice',
#   'age'],
#  960: ['perseus',
#   'demigod',
#   'son',
#   'zeus',
#   'battles',
#   'minions',
#   'underworld',
#   'stop',
#   'conquering',
#   'heaven',
#   'earth'],
#  961: ['following',
#   'clues',
#   'origin',
#   'mankind',
#   'team',
#   'finds',
#   'structure',
#   'distant',
#   'moon',
#   'soon',
#   'realize',
#   'alone'],
#  962: ['expansion',
#   'universe',
#   'robert',
#   'ludlums',
#   'novels',
#   'centered',
#   'new',
#   'hero',
#   'whose',
#   'stakes',
#   'triggered',
#   'events',
#   'previous',
#   'three',
#   'films'],
#  963: ['batman',
#   'robin',
#   'try',
#   'keep',
#   'relationship',
#   'together',
#   'even',
#   'must',
#   'stop',
#   'mr',
#   'freeze',
#   'poison',
#   'ivy',
#   'freezing',
#   'gotham',
#   'city'],
#  964: ['man',
#   'goes',
#   'virtual',
#   'vacation',
#   'memories',
#   'planet',
#   'mars',
#   'unexpected',
#   'harrowing',
#   'series',
#   'events',
#   'forces',
#   'go',
#   'planet',
#   'real'],
#  965: ['man',
#   'fallen',
#   'love',
#   'wrong',
#   'woman',
#   'sent',
#   'sultan',
#   'diplomatic',
#   'mission',
#   'distant',
#   'land',
#   'ambassador',
#   'stopping',
#   'viking',
#   'village',
#   'port',
#   'restock',
#   'supplies',
#   'finds',
#   'unwittingly',
#   'embroiled',
#   'quest',
#   'banish',
#   'mysterious',
#   'threat',
#   'distant',
#   'viking',
#   'land'],
#  966: ['outskirts',
#   'whoville',
#   'lives',
#   'green',
#   'revengeseeking',
#   'grinch',
#   'plans',
#   'ruining',
#   'christmas',
#   'holiday',
#   'citizens',
#   'town'],
#  967: ['secret',
#   'agent',
#   'sent',
#   'sydney',
#   'find',
#   'destroy',
#   'genetically',
#   'modified',
#   'disease',
#   'called',
#   'chimera'],
#  968: ['unusually',
#   'intense',
#   'storm',
#   'pattern',
#   'catches',
#   'commercial',
#   'fishermen',
#   'unaware',
#   'puts',
#   'mortal',
#   'danger'],
#  969: ['fantastic',
#   'four',
#   'learn',
#   'arent',
#   'superpowered',
#   'beings',
#   'universe',
#   'square',
#   'powerful',
#   'silver',
#   'surfer',
#   'planeteating',
#   'galactus'],
#  970: ['young',
#   'man',
#   'survives',
#   'disaster',
#   'sea',
#   'hurtled',
#   'epic',
#   'journey',
#   'adventure',
#   'discovery',
#   'cast',
#   'away',
#   'forms',
#   'unexpected',
#   'connection',
#   'another',
#   'survivor',
#   'fearsome',
#   'bengal',
#   'tiger'],
#  971: ['stunt',
#   'motorcyclist',
#   'johnny',
#   'blaze',
#   'gives',
#   'soul',
#   'become',
#   'hellblazing',
#   'vigilante',
#   'fight',
#   'power',
#   'hungry',
#   'blackheart',
#   'son',
#   'devil'],
#  972: ['cias',
#   'dangerous',
#   'former',
#   'operative',
#   'drawn',
#   'hiding',
#   'uncover',
#   'explosive',
#   'truths',
#   'past'],
#  973: ['angels',
#   'investigate',
#   'series',
#   'murders',
#   'occur',
#   'theft',
#   'witness',
#   'protection',
#   'profile',
#   'database'],
#  974: ['year',
#   'wealthy',
#   'live',
#   'manmade',
#   'space',
#   'station',
#   'rest',
#   'population',
#   'resides',
#   'ruined',
#   'earth',
#   'man',
#   'takes',
#   'mission',
#   'could',
#   'bring',
#   'equality',
#   'polarized',
#   'worlds'],
#  975: ['veteran',
#   'assigned',
#   'extract',
#   'earths',
#   'remaining',
#   'resources',
#   'begins',
#   'question',
#   'knows',
#   'mission'],
#  976: ['stuart', 'snowbell', 'set', 'across', 'town', 'rescue', 'friend'],
#  977: ['detroit',
#   'alex',
#   'murphy',
#   'loving',
#   'husband',
#   'father',
#   'good',
#   'cop',
#   'critically',
#   'injured',
#   'line',
#   'duty',
#   'multinational',
#   'conglomerate',
#   'omnicorp',
#   'sees',
#   'chance',
#   'partman',
#   'partrobot',
#   'police',
#   'officer'],
#  978: ['wanted',
#   'criminal',
#   'riddick',
#   'arrives',
#   'planet',
#   'called',
#   'helion',
#   'prime',
#   'finds',
#   'invading',
#   'empire',
#   'called',
#   'necromongers',
#   'army',
#   'plans',
#   'convert',
#   'kill',
#   'humans',
#   'universe'],
#  979: ['four',
#   'young',
#   'outsiders',
#   'teleport',
#   'alternate',
#   'dangerous',
#   'universe',
#   'alters',
#   'physical',
#   'form',
#   'shocking',
#   'ways',
#   'four',
#   'must',
#   'learn',
#   'harness',
#   'new',
#   'abilities',
#   'work',
#   'together',
#   'save',
#   'earth',
#   'former',
#   'friend',
#   'turned',
#   'enemy'],
#  980: ['young',
#   'driver',
#   'speed',
#   'racer',
#   'aspires',
#   'champion',
#   'racing',
#   'world',
#   'help',
#   'family',
#   'hightech',
#   'mach',
#   'automobile'],
#  981: ['man',
#   'living',
#   'futuristic',
#   'sterile',
#   'colony',
#   'begins',
#   'question',
#   'circumscribed',
#   'existence',
#   'friend',
#   'chosen',
#   'go',
#   'island',
#   'last',
#   'uncontaminated',
#   'place',
#   'earth'],
#  982: ['cut',
#   'usa',
#   'softball',
#   'team',
#   'feeling',
#   'bit',
#   'past',
#   'prime',
#   'lisa',
#   'finds',
#   'evaluating',
#   'life',
#   'middle',
#   'love',
#   'triangle',
#   'corporate',
#   'guy',
#   'crisis',
#   'competes',
#   'current',
#   'baseballplaying',
#   'beau'],
#  983: ['bergens',
#   'invade',
#   'troll',
#   'village',
#   'poppy',
#   'happiest',
#   'troll',
#   'ever',
#   'born',
#   'curmudgeonly',
#   'branch',
#   'set',
#   'journey',
#   'rescue',
#   'friends'],
#  984: ['young',
#   'woman',
#   'gets',
#   'mixed',
#   'disgraced',
#   'spy',
#   'trying',
#   'clear',
#   'name'],
#  985: ['two',
#   'jedi',
#   'knights',
#   'escape',
#   'hostile',
#   'blockade',
#   'find',
#   'allies',
#   'come',
#   'across',
#   'young',
#   'boy',
#   'may',
#   'bring',
#   'balance',
#   'force',
#   'long',
#   'dormant',
#   'sith',
#   'resurface',
#   'claim',
#   'old',
#   'glory'],
#  986: ['three',
#   'years',
#   'clone',
#   'wars',
#   'jedi',
#   'rescue',
#   'palpatine',
#   'count',
#   'dooku',
#   'obiwan',
#   'pursues',
#   'new',
#   'threat',
#   'anakin',
#   'acts',
#   'double',
#   'agent',
#   'jedi',
#   'council',
#   'palpatine',
#   'lured',
#   'sinister',
#   'plan',
#   'rule',
#   'galaxy'],
#  987: ['ten',
#   'years',
#   'initially',
#   'meeting',
#   'anakin',
#   'skywalker',
#   'shares',
#   'forbidden',
#   'romance',
#   'padmé',
#   'obiwan',
#   'investigates',
#   'assassination',
#   'attempt',
#   'senator',
#   'discovers',
#   'secret',
#   'clone',
#   'army',
#   'crafted',
#   'jedi'],
#  988: ['wolverine',
#   'summoned',
#   'japan',
#   'old',
#   'acquaintance',
#   'embroiled',
#   'conflict',
#   'forces',
#   'confront',
#   'demons'],
#  989: ['vulcanologist',
#   'arrives',
#   'countryside',
#   'town',
#   'recently',
#   'named',
#   'second',
#   'desirable',
#   'place',
#   'live',
#   'america',
#   'discovers',
#   'long',
#   'dormant',
#   'volcano',
#   'dantes',
#   'peak',
#   'may',
#   'wake',
#   'moment'],
#  990: ['eric',
#   'fellow',
#   'warrior',
#   'sara',
#   'raised',
#   'members',
#   'ice',
#   'queen',
#   'freyas',
#   'army',
#   'try',
#   'conceal',
#   'forbidden',
#   'love',
#   'fight',
#   'survive',
#   'wicked',
#   'intentions',
#   'freya',
#   'sister',
#   'ravenna'],
#  991: ['two',
#   'us',
#   'marines',
#   'wwii',
#   'assigned',
#   'protect',
#   'navajo',
#   'marines',
#   'use',
#   'native',
#   'language',
#   'unbreakable',
#   'radio',
#   'cypher'],
#  992: ['astérix',
#   'obélix',
#   'compete',
#   'olympics',
#   'order',
#   'help',
#   'friend',
#   'lovesix',
#   'marry',
#   'princess',
#   'irina',
#   'brutus',
#   'also',
#   'tries',
#   'win',
#   'game',
#   'team',
#   'get',
#   'rid',
#   'father',
#   'julius',
#   'caesar'],
#  993: ['travel',
#   'writer',
#   'lemuel',
#   'gulliver',
#   'takes',
#   'assignment',
#   'bermuda',
#   'ends',
#   'island',
#   'liliput',
#   'towers',
#   'tiny',
#   'citizens'],
#  994: ['two',
#   'astronauts',
#   'work',
#   'together',
#   'survive',
#   'accident',
#   'leaves',
#   'alone',
#   'space'],
#  995: ['newly',
#   'recruited',
#   'night',
#   'security',
#   'guard',
#   'museum',
#   'natural',
#   'history',
#   'discovers',
#   'ancient',
#   'curse',
#   'causes',
#   'animals',
#   'exhibits',
#   'display',
#   'come',
#   'life',
#   'wreak',
#   'havoc'],
#  996: ['bored',
#   'married',
#   'couple',
#   'surprised',
#   'learn',
#   'assassins',
#   'hired',
#   'competing',
#   'agencies',
#   'kill'],
#  997: ['aftermath',
#   'massive',
#   'earthquake',
#   'california',
#   'rescuechopper',
#   'pilot',
#   'makes',
#   'dangerous',
#   'journey',
#   'exwife',
#   'across',
#   'state',
#   'order',
#   'rescue',
#   'daughter'],
#  998: ['evil',
#   'wizard',
#   'gargamel',
#   'chases',
#   'tiny',
#   'blue',
#   'smurfs',
#   'village',
#   'tumble',
#   'magical',
#   'world',
#   'new',
#   'york',
#   'city'],
#  999: ['john',
#   'mcclane',
#   'young',
#   'hacker',
#   'join',
#   'forces',
#   'take',
#   'master',
#   'cyberterrorist',
#   'thomas',
#   'gabriel',
#   'washington',
#   'dc'],
#  ...}

# %% [markdown]
# ## Understanding Term Frequency (TF)
#
# $$
# tf(t, d) = \frac{n_{t}} {\sum_{k} n_{k}}
# $$
#
# _Term Frequency_ is a normalised metric that measures how frequent a certain term $t$ is in a given document $d$. In the formula above ${n_{t}}$ stands for the number of times the term $t$ occur in document $d$ while $\sum_{k} n_{k}$ is the sum of all terms in the document (its length in other words). Note that term $t$ can potentially occur many times in $d$ hence the need to normalise the metric over the sum of all terms. Below is a function definition `calculate_tf` which takes as input the `tokens` of a certain document $d$ and counts the number of occurences of each terms in the document and calculate their normalised frequency.

# %%
def calculate_tf(tokens):
    unique_tokens = set(tokens)
    term_count = dict.fromkeys(unique_tokens, 0)
    term_frequency = dict.fromkeys(unique_tokens, 0)
    N = float(len(tokens))
    for term in tokens:
        term_count[term] += 1
        term_frequency[term] += 1 / N
    return term_count, term_frequency

# %% [markdown]
# Considering the function `calculate_tf` above, augment your custom dictionary with both the `term_count` and normalised `term_frequency` given the respective plot's `tokens` you previously computed.

# %%
test = ['former',
  'fbi',  
  'fbi',
  'officer',
  'works',
  'security',
  'expert',
  'las',
  'vegas',
  'recruited',
  'mysterious',
  'pit',
  'boss',
  'mr',
  'johnson',
  'based',
  'tips',
  'try',
  'prevent',
  'crimes',
  'rich',
  'place',
  'bets',
  'chances',
  'success']

calculate_tf(test)
# Out:
# ({'tips': 1,
#   'based': 1,
#   'works': 1,
#   'bets': 1,
#   'place': 1,
#   'fbi': 2,
#   'mysterious': 1,
#   'johnson': 1,
#   'recruited': 1,
#   'try': 1,
#   'former': 1,
#   'success': 1,
#   'las': 1,
#   'pit': 1,
#   'security': 1,
#   'officer': 1,
#   'boss': 1,
#   'prevent': 1,
#   'chances': 1,
#   'mr': 1,
#   'expert': 1,
#   'crimes': 1,
#   'vegas': 1,
#   'rich': 1},
#  {'tips': 0.04,
#   'based': 0.04,
#   'works': 0.04,
#   'bets': 0.04,
#   'place': 0.04,
#   'fbi': 0.08,
#   'mysterious': 0.04,
#   'johnson': 0.04,
#   'recruited': 0.04,
#   'try': 0.04,
#   'former': 0.04,
#   'success': 0.04,
#   'las': 0.04,
#   'pit': 0.04,
#   'security': 0.04,
#   'officer': 0.04,
#   'boss': 0.04,
#   'prevent': 0.04,
#   'chances': 0.04,
#   'mr': 0.04,
#   'expert': 0.04,
#   'crimes': 0.04,
#   'vegas': 0.04,
#   'rich': 0.04})

# %% [markdown]
# ## Understanding Inverse Document Frequency (IDF)
#
# $$
# idf(t, D) = \log\frac{|D|}{|{d_{i} \in D : t \in d_{i}}|}
# $$
#
# _Inverse Document Frequency_ is a metric that measures of important a term $t$ is in a given corpus (or collection) $D$ of documents $d_{i}$. While _Term Frequency_ measures the frequency of a term $t$ in a single document $d$, here _IDF_ consider frequency of a term $t$ over the whole corpus $D$ as to derive a weight on the statistical significance of term $t$ overall. The idea here is that common words which occur in many documents ("man" or a stop word like "it" for example) hold little importance overall as they are redundant. What _IDF_ does is to give more weight to words that are uncommon overall yet possibly significant for certain documents. This is the reason why the metric takes the $\log$ of the fraction $\frac{|D|}{|{d_{i} \in D : t \in d_{i}}|}$ where $|D|$ is the number of documents in corpus $D$ and $|{d_{i} \in D : t \in d_{i}}|$ is the number of times a term $t$ appears in a document in the corpus.

# %% [markdown]
# The first thing we need to do to calculate _IDF_ is to establish the overall vocabulary of the entire corpus. What are all the unique words (or terms) in all of our plots? How many unique words do we have? Consider the following `bag_of_words` python set and fill it with all the unique terms present in our plots.

# %%
# Vocabulary -> bag of words

bag_of_words = set()

for plot in pre_

# %% [markdown]
# Now, remember we calculated a `term_count` for each term in each document when we calculated the _TF_ with `calculate_tf` above? We need to use this pre-calculated informatin here to derive $|{d_{i} \in D : t \in d_{i}}|$ which is the number of times a term $t$ appears in a document in the corpus. Make a list of each `term_count` you recorded in your custom dicitonary as to use it to computer _IDF_ below.

# %%
list_all_documents_count = # code goes here

# %% [markdown]
# Here is function defintion `calculate_idf` that computes the _IDF_ of all the terms in our corpus. It takes a list of `term_count` as `documents_count_list` and a overall vocabulary as `bag_of_words`. Can you make sense of the function in light of the $idf(t, D)$ formula above?

# %%
import math

def calculate_idf(documents_count_list, bag_of_words):
    
    idf = dict.fromkeys(bag_of_words, 0)
    D = len(documents_count_list)
    
    for d in documents_count_list:
        for term, count in d.items():
            if count > 0:
                idf[term] += 1
                
    for term, document_count in idf.items():
        idf[term] = math.log(D / float(document_count))
        
    return idf

# %% [markdown]
# Lets calculate the _IDF_ then using the function above. What are the highest weight? What are the lowest weight?

# %%
# code goes here

# %% [markdown]
# ## Putting it together: TF-IDF
#
# $$
# tf-idf(t, d, D) = tf(t, d) \cdot idf(t, D)
# $$
#
# Putting _TF_ and _IDF_ together is quite simple. Since _IDF_ is a weight for each term in the corpus, simply multiply the terms' weight value to all the _TF_ we already have calculated. Here is a function `calculate_tf_idf` that does just that!

# %%
def calculate_tf_idf(tf, idf):
    tf_idf = dict.fromkeys(tf.keys(), 0)
    for term, frequency in tf.items():
        tf_idf[term] = frequency * idf[term]
    return tf_idf

# %% [markdown]
# With the function above, calculate the _TF-IDF_ of all plots in your custom dictionary and record the results in the dictionary itself.

# %%
# code goes here

# %% [markdown]
# What is the difference between _TF_ and _IDF_ for a given plot?

# %%
# code goes here

# %% [markdown]
# ## Save the data
#
# Save your custom dictionary you have constructed above in a json file.

# %%
import json

# code goes here
